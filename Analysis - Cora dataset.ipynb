# %%
# Source: https://alchemy.cs.washington.edu/mlns/er/
# Entity Resolution with Markov Logic
# Parag Singla, Pedro Domingos
'''
"The hand-labeled Cora dataset is provided by McCallum2
and has previously been used by Bilenko and Mooney [3]
and others. This dataset is a collection of 1295 different citations
to computer science research papers from the Cora
Computer Science Research Paper Engine. The original
dataset contains only unsegmented citation strings. Bilenko
and Mooney [3] segmented each citation into fields (author,
venue, title, publisher, year, etc.) using an information
extraction system. We used this processed version of
Cora. We further cleaned it up by correcting some labels.
This cleaned version contains references to 132 different research
papers. We used only the three most informative
fields: first author, title and venue (with venue including
conferences, journals, workshops, etc.). We compared the
performance of the algorithms for the task of de-duplicating
citations, authors and venues. For training and testing purposes,
we hand-labeled the field pairs. The labeled data
contains references to 50 authors and 103 venues. After
forming canopies, the total number of match decisions was
61,177."

[3] M. Bilenko and R. Mooney. Adaptive duplicate detection
using learnable string similarity measures. In Proc. KDD-
03, pages 39–48, 2003
'''
print()

# %%
# Working directory
wdir = 'data/cora-uwash'

# Read and convert the dataset into a friendlier format

import xml.etree.ElementTree as ET
import os.path
from xml.etree.ElementTree import ParseError

database= []
exit = False
for fpath in [os.path.join(wdir,fname) for fname in ['cora0.txt','cora1.txt','cora2.txt']]:
    d = {}
    f = open(fpath)
    for line in f:
        if line.strip() == '':
            database.append(d)
            d = dict()
        else:
            try:
                root = ET.fromstring('<root>'+line.strip().replace('&','&amp;')+'</root>')
                for child in root:
                    if child.tag == 'meta':
                        for attrname,attrvalue in child.attrib.items():
                            d[attrname] = attrvalue
                    else:
                        d[child.tag] = child.text
            except ParseError as perr:
                print(perr)
                print(line)
                exit = True
                break
    if exit:
        break

# %%
# Validation1: "This dataset is a collection of 1295 different citations"
len(database)
# Out:
# 1295

# %%
import json
json.dump(database,open(os.path.join(wdir,'cora0+1+2.json'),'w'))

# %%
import pandas as pd
df = pd.DataFrame(database)

# %%
df
# Out:
#                       address  \
# 0                         NaN
# 1                         NaN
# 2              san francisco:
# 3              palo alto, ca.
# 4              san mateo, ca.
# 5                         NaN
# 6                         NaN
# 7              san mateo, ca.
# 8             san ma-teo, ca.
# 9                      42-49,
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13             san mateo, ca,
# 14                     42-49,
# 15                        NaN
# 16       san mateo, ca, 1993.
# 17       san mateo, ca, 1993.
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24       san mateo, ca, 1992.
# 25             san mateo, ca,
# 26             san mateo, ca.
# 27     san mateo, california.
# 28             san mateo, ca.
# 29             san mateo, ca.
# ...                       ...
# 1265           cambridge, ma,
# 1266                      NaN
# 1267                      NaN
# 1268                      NaN
# 1269                      NaN
# 1270                      NaN
# 1271                      NaN
# 1272          cam bridge, ma,
# 1273                      NaN
# 1274                      NaN
# 1275                      NaN
# 1276                      NaN
# 1277                      NaN
# 1278                      NaN
# 1279                      NaN
# 1280                      NaN
# 1281                      NaN
# 1282                      NaN
# 1283                      NaN
# 1284                      NaN
# 1285                      NaN
# 1286                      NaN
# 1287                      NaN
# 1288                      NaN
# 1289                      NaN
# 1290                      NaN
# 1291                      NaN
# 1292                      NaN
# 1293                      NaN
# 1294                      NaN
#
#                                                  author bib_no  \
# 0               h. drucker, r. schapire, and p. simard.   0001
# 1               h. drucker, r. schapire, and p. simard.   0002
# 2                  drucker h., schapire r., & simard p.   0003
# 3                  drucker h., schapire r., & simard p.   0004
# 4                  drucker h., schapire r., & simard p.   0005
# 5                  drucker h., schapire r., & simard p.   0006
# 6                drucker h., schapire r., and simard p.   0007
# 7                drucker h., schapire r., and simard r.   0008
# 8     drucker harris, schapire, robert, and simard p...   0009
# 9                    drucker h., schapire r., simard p.   0010
# 10                        drucker, schapire, and simard   0011
# 11    harris drucker, robert schapire, and patrice s...   0012
# 12    harris drucker, robert schapire, and patrice s...   0013
# 13               h. drucker, r. schapire, and p. simard   0014
# 14                   drucker h., schapire r., simard p.   0015
# 15    harris drucker, robert schapire, and patrice s...   0016
# 16    harris drucker, robert schapire, and patrice s...   0017
# 17    harris drucker, robert e. schapire, and ptrice...   0018
# 18                    h. druker, r. schapire, p. simard   0019
# 19                        drucker h., r. schapire, & p.   0020
# 20                 drucker h., schapire r., & simard p.   0021
# 21                                        r., & hart p.   0022
# 22                 yoav freund, and robert e. schapire.   0023
# 23                 yoav freund, and robert e. schapire.   0024
# 24    y. freund, h. s. seung, e. shamir, and n. tishby.   0025
# 25    yoav freund, h. sebastian seung, eli shamir, a...   0026
# 26       freund y., seung h. s., shamir e., & tishby n.   0027
# 27          freund y., seung h., shamir e., & tishby n.   0028
# 28        freund y., seung h., shamir e., and tishby n.   0029
# 29      freund y., seung h.s., shamir e., and tishby n.   0030
# ...                                                 ...    ...
# 1265                                    r. e. schapire.   2418
# 1266                                robert e. schapire.   2419
# 1267                                      schapire r.e.   2420
# 1268                                      schapire r.e.   2421
# 1269                                robert e. schapire.   2422
# 1270                                robert e. schapire.   2423
# 1271                                robert e. schapire.   2424
# 1272                                    r. e. schapire.   2425
# 1273                      r. e. schapire, l. m. sellie.   2426
# 1274    schapire r.e., freund y., bartlett p., lee w.s.   2427
# 1275  r. e. schapire, y. freund, p. bartlett, and w....   2428
# 1276  schapire r. e., freund y., bartlett p., & lee ...   2429
# 1277  schapire r. e., freund y., bartlett p., & lee ...   2430
# 1278    schapire r., freund y., bartlett p., and lee w.   2431
# 1279        schapire r., y. freund, p. bartlett, and w.   2432
# 1280  schapire r.e., freund y., bartlett p., and lee...   2433
# 1281  schapire r.e., freund y., bartlett p., and lee...   2434
# 1282  schapire r.e., freund y., bartlett p., and lee...   2435
# 1283  schapire r.e., freund y., bartlett p., and lee...   2436
# 1284                       schapire r.e., y. freund, p.   2437
# 1285       shapire r., freund y., bartlett p., & lee w.   2438
# 1286  r. schapire, y. freund, p. bartlett, and w. s....   2439
# 1287  schapire r. e., freund y., bartlett p., & lee ...   2440
# 1288  robert e. schapire, yoav freund, peter bartlet...   2441
# 1289  robert e. schapire, yoav freund, peter bartlet...   2442
# 1290  robert e. schapire, yoav freund, peter bartlet...   2443
# 1291  robert e. schapire, yoav freund, peter bartlet...   2444
# 1292              r.e. schapire, y. freund, p. bartlett   2445
# 1293   r. schapire, y. freund, p. bartlett, and w. lee.   2446
# 1294    schapire, r.e., freund y., bartlett p., and lee   2447
#
#             class_no                                             editor  \
# 0        drucker1992   in steven j. hanson, jack d. cowan, and c. le...
# 1        drucker1992   in steven j. hanson, jack d. cowan, and c. le...
# 2        drucker1992                                                NaN
# 3        drucker1992    in hanson, j., cowan, j., & giles, c., editors,
# 4        drucker1992   in hanson, s. j., cowan, j. d., & giles, c. l...
# 5        drucker1992                                                NaN
# 6        drucker1992   in hanson, s. j., cowan, j. d., and giles, c....
# 7        drucker1992   in hanson, s. j., cowan, j. d., and giles, c....
# 8        drucker1992                                                NaN
# 9        drucker1992           s. j. hanson, j. cowan, l. giles (eds.),
# 10       drucker1992                                                NaN
# 11       drucker1992   in steven j. hanson, jack d. cowan, and c. le...
# 12       drucker1992                                                NaN
# 13       drucker1992   s. j. han-son, j. d. cowan, and c. l. giles, ...
# 14       drucker1992           s. j. hanson, j. cowan, l. giles (eds.),
# 15       drucker1992                                                NaN
# 16       drucker1992                                                NaN
# 17       drucker1992                                                NaN
# 18       drucker1992                                                NaN
# 19       drucker1992                                                NaN
# 20       drucker1992            in s. hanson, j. cowan & c. giles, eds,
# 21     drucker1992C1   in hanson, s. j., cowan, j. d., & giles, c. l...
# 22       freund0000a                                                NaN
# 23       freund0000a                                                NaN
# 24       freund1992a                                                NaN
# 25       freund1992a   in stephen jose hanson, jack d. cowan, and c....
# 26       freund1992a   in hanson, s. j., cowan, j. d., & giles, c. l...
# 27       freund1992a                                                NaN
# 28       freund1992a   in hanson, s. j., cowan, j. d., and giles, c....
# 29       freund1992a                                                NaN
# ...              ...                                                ...
# 1265    schapire1991                                                NaN
# 1266    schapire1991                                                NaN
# 1267    schapire1991                                                NaN
# 1268    schapire1991                                                NaN
# 1269  schapire1991C1                                                NaN
# 1270   schapire1991l                                                NaN
# 1271   schapire1991l                                                NaN
# 1272    schapire1992                                                NaN
# 1273    schapire1993                                                NaN
# 1274    schapire1997                                                NaN
# 1275    schapire1997                                                NaN
# 1276    schapire1997                                 in d. fisher, ed.,
# 1277    schapire1997                                 in d. fisher, ed.,
# 1278    schapire1997                                                NaN
# 1279    schapire1997                                                NaN
# 1280    schapire1997                                                NaN
# 1281    schapire1997                                                NaN
# 1282    schapire1997                                                NaN
# 1283    schapire1997                                                NaN
# 1284    schapire1997                                                NaN
# 1285    schapire1997                                                NaN
# 1286    schapire1997                                                NaN
# 1287    schapire1997                                                NaN
# 1288    schapire1997                                                NaN
# 1289    schapire1997                                                NaN
# 1290    schapire1997                                                NaN
# 1291    schapire1997                                                NaN
# 1292    schapire1997                                                NaN
# 1293    schapire1997                                                NaN
# 1294    schapire1997                                                NaN
#
#                                 institution    month  \
# 0                                       NaN      NaN
# 1                                       NaN      NaN
# 2                                       NaN      NaN
# 3                                       NaN      NaN
# 4                                       NaN      NaN
# 5                                       NaN      NaN
# 6                                       NaN      NaN
# 7                                       NaN      NaN
# 8                                       NaN      NaN
# 9                                       NaN      NaN
# 10                                      NaN      NaN
# 11                                      NaN      NaN
# 12                                      NaN      NaN
# 13                                      NaN      NaN
# 14                                      NaN      NaN
# 15                                      NaN      NaN
# 16                                      NaN      NaN
# 17                                      NaN      NaN
# 18                                      NaN      NaN
# 19                                      NaN    simad
# 20                                      NaN      NaN
# 21                                      NaN      NaN
# 22                                      NaN      NaN
# 23                                      NaN      NaN
# 24                                      NaN      NaN
# 25                                      NaN      NaN
# 26                                      NaN      NaN
# 27                                      NaN      NaN
# 28                                      NaN      NaN
# 29                                      NaN      NaN
# ...                                     ...      ...
# 1265                                    NaN      NaN
# 1266                                m.i.t.,      NaN
# 1267                                    NaN       15
# 1268                                    NaN      NaN
# 1269   mit laboratory for computer science,      NaN
# 1270                                    NaN   august
# 1271                                    NaN   august
# 1272                                    NaN      NaN
# 1273                                    NaN    july,
# 1274                                    NaN      NaN
# 1275                                    NaN      NaN
# 1276                                    NaN      NaN
# 1277                                    NaN      NaN
# 1278                                    NaN      NaN
# 1279                                    NaN      NaN
# 1280                                    NaN      NaN
# 1281                                    NaN      NaN
# 1282                                    NaN      NaN
# 1283                                    NaN      NaN
# 1284                                    NaN      NaN
# 1285                                    NaN      NaN
# 1286                                    NaN      NaN
# 1287                                    NaN      NaN
# 1288                                    NaN        9
# 1289                                    NaN      NaN
# 1290                                    NaN      NaN
# 1291                                    NaN      NaN
# 1292                                    NaN      NaN
# 1293                                    NaN      NaN
# 1294                                    NaN      NaN
#
#                                                    note            pages  \
# 0                                                   NaN     pages 42-49.
# 1                                                   NaN     pages 42-49.
# 2                                                   NaN              NaN
# 3                                                   NaN     (pp. 42-49),
# 4                                                   NaN              NaN
# 5                                                   NaN           42-49.
# 6                                                   NaN     pages 42-49.
# 7                                                   NaN     pages 42-49,
# 8                                                   NaN           42-49.
# 9                                                   NaN              NaN
# 10                                                  NaN        42-49. 14
# 11                                                  NaN     pages 42-49.
# 12                                                  NaN              NaN
# 13                                                  NaN       pp. 42-49,
# 14                                                  NaN              NaN
# 15                                                  NaN     pages 42-49,
# 16                                                  NaN     pages 42-49,
# 17                                                  NaN              NaN
# 18                                                  NaN           42-49.
# 19                                                  NaN       pp. 42-49.
# 20                                                  NaN       pp. 42-49.
# 21                           morgan kaufmann. 198 duda,     (pp. 42-49).
# 22                                         (to appear).              NaN
# 23                                         (to appear).              NaN
# 24                                                  NaN              NaN
# 25                                                  NaN   pages 483-490.
# 26                                                  NaN   (pp. 483-490).
# 27                                                  NaN              NaN
# 28                                                  NaN   pages 483-490,
# 29                                                  NaN         483-490.
# ...                                                 ...              ...
# 1265                                                NaN              NaN
# 1266                                                NaN              NaN
# 1267                                                NaN              NaN
# 1268                                                NaN              NaN
# 1269                                                NaN              NaN
# 1270                                                NaN              NaN
# 1271                                                NaN   pages 184-198,
# 1272                                                NaN              NaN
# 1273                                                NaN              NaN
# 1274                                                NaN              NaN
# 1275                                                NaN              NaN
# 1276                                                NaN     pp. 322-330.
# 1277                                           322-330.              pp.
# 1278                                                NaN              NaN
# 1279   (available at http://www.research.att.com/~yo...              NaN
# 1280                                                NaN              NaN
# 1281                                                NaN              NaN
# 1282                                                NaN              NaN
# 1283                                                NaN         322-330.
# 1284                                                NaN     pp. 322-330.
# 1285                                                NaN              NaN
# 1286                                      to appear. 11              NaN
# 1287                                                NaN              NaN
# 1288                                                NaN              NaN
# 1289                                                NaN              NaN
# 1290                                                NaN              NaN
# 1291                                                NaN              NaN
# 1292                                                NaN                1
# 1293                                                NaN    pages 322330,
# 1294                                                NaN         322-330.
#
#                                publisher ref_no  \
# 0                       morgan kaufmann,   0095
# 1                       morgan kaufmann,   0096
# 2                       morgan kaufmann.   0097
# 3                       morgan kaufmann.   0098
# 4                       morgan kaufmann,   0099
# 5                                    NaN   0100
# 6                       morgan kaufmann.   0101
# 7                       morgan kaufmann.   0102
# 8                       morgan kaufmann.   0103
# 9                       morgan kaufmann.   0104
# 10                                   NaN   0105
# 11                      morgan kaufmann,   0106
# 12                      morgan kaufmann,   0107
# 13                      morgan kaufmann.   0108
# 14                      morgan kaufmann.   0109
# 15                                   NaN   0110
# 16                      morgan kaufmann.   0111
# 17                      morgan kaufmann.   0112
# 18                      morgan kaufmann,   0113
# 19                                   NaN   0114
# 20                     morgan kauffmann,   0115
# 21                       addison-wesley.   0116
# 22                                   NaN   0181
# 23                                   NaN   0182
# 24                      morgan kaufmann.   0183
# 25                      morgan kaufmann,   0184
# 26                      morgan kaufmann,   0185
# 27                      morgan kaufmann,   0186
# 28                      morgan kaufmann.   0187
# 29                      morgan kaufmann.   0188
# ...                                  ...    ...
# 1265                          mit press,   1243
# 1266                                 NaN   1244
# 1267                      the mit press,   1245
# 1268                      the mit press,   1246
# 1269                                 NaN   1247
# 1270                                 NaN   1249
# 1271                                 NaN   1250
# 1272                          mit press,   1251
# 1273                                 NaN   1253
# 1274                    morgan kaufmann,   1263
# 1275                                 NaN   1264
# 1276                    morgan kaufmann,   1265
# 1277                    morgan kaufmann,   1266
# 1278                                 NaN   1267
# 1279                                 NaN   1268
# 1280     morgan kaufmann (1997) 322-330.   1269
# 1281     morgan kaufmann (1997) 322-330.   1270
# 1282                                 NaN   1271
# 1283                    morgan kaufmann.   1272
# 1284                    morgan kaufmann.   1273
# 1285                                 NaN   1274
# 1286   morgan kaufmann publishers, inc.,   1275
# 1287                                 NaN   1276
# 1288                                 NaN   1277
# 1289                                 NaN   1278
# 1290                                 NaN   1279
# 1291                                 NaN   1280
# 1292                                 NaN   1281
# 1293                                 NaN   1282
# 1294                    morgan kaufmann.   1283
#
#                                                   title  \
# 0      improving performance in neural networks usin...
# 1      improving performance in neural networks usin...
# 2      improving performance in neural networks usin...
# 3      improving performance in neural networks usin...
# 4      improving performance in neural networks usin...
# 5      improving the performance in neural networks ...
# 6      improving performance in neural networks usin...
# 7      improving performance in neural networks usin...
# 8     improving performance in neural networks using...
# 9     'improving performance in neural networks usin...
# 10     improving performance in neural networks usin...
# 11     improving performance in neural networks usin...
# 12     improving performance in neural networks usin...
# 13     'improving performance in neural networks usi...
# 14    'improving performance in neural networks usin...
# 15     improving performance in neural networks usin...
# 16     improving performance in neural networks usin...
# 17     improving performance in neural networks usin...
# 18     improving performance in neural networks usin...
# 19     improving the performance in neural networks ...
# 20     improving performance in neural networks usin...
# 21           pattern classification and scene analysis.
# 22     adaptive game playing using multiplicative we...
# 23     adaptive game playing using multiplicative we...
# 24     information, prediction, and query by committee.
# 25     information, prediction, and query by committee.
# 26     information, prediction, and query by committee.
# 27     information, prediction, and query by committee,
# 28       information, prediction and query by comittee.
# 29     information, prediction, and query by committee.
# ...                                                 ...
# 1265   the design and analysis of efficient learning...
# 1266   the design and analysis of efficient learning...
# 1267   the design and analysis of efficient learning...
# 1268   the design and analysis of efficient learning...
# 1269   the design and analysis of efficient learning...
# 1270   learning probabilistic read-once formulas on ...
# 1271   learning probabilistic read-once formulas on ...
# 1272   the design and analysis of ef ficient learnin...
# 1273   learning sparse multivariate polynomial over ...
# 1274   boosting the margin: a new explanation for th...
# 1275   boosting the margin: a new explanation for th...
# 1276   boosting the margin: a new explanation for th...
# 1277   boosting the margin: a new explanation for th...
# 1278   boosting the margin: a new explanation for th...
# 1279   lee (1997). boosting the margin : a new expla...
# 1280   boosting the margin: a new explanation for th...
# 1281  : boosting the margin: a new explanation for t...
# 1282                               boosting the margin:
# 1283   boosting the margin: a new explanation for th...
# 1284   bartlett & w.s. lee (1997), boosting the marg...
# 1285   boosting the margin: a new explanation for th...
# 1286   boosting the margin; a new explanation for th...
# 1287   boosting the margin: a new explanation for th...
# 1288   boosting the margin: a new explanation for th...
# 1289   boosting the margin: a new explanation for th...
# 1290   boosting the margin: a new explanation for th...
# 1291   boosting the margin: a new explanation for th...
# 1292   and w.s. leee. boosting the margin: a new exp...
# 1293   boosting the margin: a new explanation for th...
# 1294   w.s. boosting the margin: a new explanation f...
#
#                                                   venue      volume      year
# 0      advances in neural information processing sys...   volume 5,      1993
# 1      advances in neural information processing sys...   volume 5,      1993
# 2      in advances in neural information processing ...         NaN   (1992).
# 3      advances in neural information processing sys...         NaN   (1992).
# 4      advances in neural information processing sys...         NaN   (1993).
# 5      advances in neural information processing sys...          5,   (1993).
# 6      advances in neural information processing sys...   volume 5,   (1993).
# 7      advances in neural information processing sys...         NaN      1993
# 8      in advances in neural informations processing...         NaN      1993
# 9      in advances in neural information processing ...         NaN      1993
# 10     advances in neural information processing sys...         NaN     1993,
# 11     advances in neural information processing sys...         NaN      1993
# 12     in advances in neural information processing ...         NaN      1992
# 13     in advances in neural information processing ...         NaN     1993,
# 14     in advances in neural information processing ...         NaN      1993
# 15     in advances in neural information processing ...         NaN      1993
# 16     in advances in neural informations processing...         NaN      1993
# 17     in proceedings of the fifth conf. on neural i...         NaN      1993
# 18     advances in neural information processing sys...     vol. 5,     1993,
# 19     advances in neural information processing sys...          5,   (1993),
# 20             `neural information processing systems',         NaN   (1993),
# 21     advances in neural information processing sys...   volume 5,   (1973).
# 22    games and economic behavior, in proc. of ieee ...         NaN         0
# 23    games and economic behavior, in proc. of ieee ...         NaN         0
# 24     in advances in neural informations processing...         NaN      1993
# 25     advances in neural information processing sys...   volume 5,      1993
# 26     advances in neural information processing sys...   volume 5,   (1993).
# 27     in `advances in neural information processing...     vol. 5,   (1993),
# 28     advances in neural information processing sys...   volume 5,   (1993).
# 29     in advances in neural informations processing...         NaN      1992
# ...                                                 ...         ...       ...
# 1265                                        phd thesis,         NaN      1992
# 1266                                        phd thesis,         NaN      1991
# 1267                                        phd thesis,         NaN      1992
# 1268                                        phd thesis,         NaN      1992
# 1269                   technical report mit/lcs/tr-493,         NaN      1991
# 1270   in computation learning theory: proceedings o...         NaN      1991
# 1271   in proceedings of the fourth annual workshop ...         NaN      1991
# 1272   in proceedings of the fourth annual workshop ...         NaN      1992
# 1273   in proceedings of the sixth annual acm worksh...         NaN      1993
# 1274   in proceedings of the fourteenth internationa...         NaN      1997
# 1275   in machine learning: proceedings of the fourt...         NaN   (1997).
# 1276   `machine learning: proceedings of the fourtee...         NaN   (1997),
# 1277   `machine learning: proceedings of the fourtee...         NaN   (1997),
# 1278   in proceedings of the 14th international conf...         NaN   (1997).
# 1279   in proceedings of the 14th international conf...         NaN      1997
# 1280   proceedings of the 11th international confere...         NaN      1997
# 1281   proceedings of the fourteenth international c...         NaN      1997
# 1282   proceedings of the fourteenth international c...         NaN      1997
# 1283   in proceedings of the 14th international conf...         NaN      1997
# 1284   in proceedings of the fourteenth internationa...         NaN      1997
# 1285                          snowbird 1997 conference.         NaN   (1997),
# 1286   in proceedings of the fourteenth internationa...         NaN      1997
# 1287   in proceedings of the fourteenth internationa...         NaN   (1997).
# 1288   in machine learning: proceedings of the fourt...         NaN      1997
# 1289   in machine learning: proceedings of the fourt...         NaN      1997
# 1290   in machine learning: proceedings of the fourt...         NaN      1997
# 1291   in machine learning: proceedings of the fourt...         NaN      1997
# 1292                                               1997         NaN      1997
# 1293                                        in icml-97,         NaN      1997
# 1294   in proceedings of the 14th international conf...         NaN      1997
#
# [1295 rows x 15 columns]

# %%
# Validation2: "This cleaned version contains references to 132 different research papers."
# Maybe the cleaning that they talk about eliminates two papers?
print(len(df.class_no.unique()))
df.class_no.unique()
# Out:
# 134
# array(['drucker1992', 'drucker1992C1', 'freund0000a', 'freund1992a',
#        'freund1993cC', 'freund1995e', 'freund1996c', 'freund1997a',
#        'freund1997d', 'goldman1990a', 'goldman1993', 'haussler1988C',
#        'haussler1994a', 'haussler1994aC2', 'kautz1993', 'kautz1995',
#        'kearns1994cryp', 'kearns1994d', 'kearns1994e', 'kearns1996a',
#        'kearns1996b', 'kearns1997b', 'lewis1996', 'littlestone',
#        'rivest1987d', 'rivest1989', 'rivest1992', 'rivest1992C',
#        'rivest1994', 'schapire', 'schapire1988', 'schapire1989',
#        'schapire1990', 'schapire1991C2', 'schapire1992C', 'schapire1994',
#        'schapire1996', 'schapire1996p', 'schapire1997C', 'schapire1997u',
#        'schapire1997um', 'schapire1998', 'schapire1998mm', 'auer1995a',
#        'blum1993', 'cesa', 'cesaR', 'cesaJ', 'cohen1998', 'drucker1992C2',
#        'feder1995', 'freund1992b', 'freund1993a', 'freund1993b',
#        'freund1993c', 'freund1995aC', 'freund1995d', 'freund1995f',
#        'freund1996a', 'freund1996e', 'goldman1993aC', 'haussler1988',
#        'haussler1991p', 'haussler1992', 'haussler1994', 'haussler1994aC1',
#        'haussler1996', 'helmbold1995', 'helmbold1995a', 'helmbold1995aC',
#        'helmbold1997', 'kautz1993C', 'kearns1987', 'kearns1988',
#        'kearns1988bC', 'kearns1989', 'kearns1992a', 'kearns1992c',
#        'kearns1993a', 'kearns1993b', 'kearns1993bC', 'kearns1993c',
#        'kearns1994b', 'bauer1992', 'blum1994', 'cesaC', 'dietterich1996',
#        'ehrenfeucht1988', 'ehrenfeucht1988C', 'ehrenfeucht1989',
#        'freund1992aC', 'freund1992c', 'freund1995a', 'freund1995b',
#        'freund1995c', 'freund1996b', 'freund1996d', 'freund1997b',
#        'freund1997c', 'goldman1989', 'goldman1990c', 'goldman1991',
#        'goldman1993a', 'goldman1995', 'haussler1991', 'helmbold1996',
#        'helmbold1996a', 'helmbold1997c', 'kearns1987b', 'kearns1988b',
#        'kearns1989a', 'kearns1990', 'kearns1990b', 'kearns1990c',
#        'kearns1994a', 'kearns1994c', 'kearns1995b', 'kearns1997a',
#        'kearns1997aC', 'kearns1998', 'kearns1998C', 'kearns1999a',
#        'kearns1999b', 'rivest1987', 'rivest1993', 'schapire1990C1',
#        'schapire1990C2', 'schapire1990e', 'schapire1991', 'schapire1991C1',
#        'schapire1991l', 'schapire1992', 'schapire1993', 'schapire1997'], dtype=object)

# %%
'''
"The labeled data
contains references to 50 authors and 103 venues. After
forming canopies, the total number of match decisions was
61,177."
'''
# I'm going to see if the .db files help confirm this
import importlib
import UnionFind
importlib.reload(UnionFind)

# %%
uf_authors = UnionFind.UnionFind()
with open(wdir+'/SameAuthor.txt') as f:
    for line in f:
        name1, name2 = line.strip().split(',')
        uf_authors.union(name1,name2)
        
uf_authors.printDisjointSets()
# So this gives only 21 names, which I presume are the first authors only. It's a start. 
# Why wouldn't they give the labeled data containing 50 authors though, if they did indeed label it :/
# Out:
# Disjoint sets:
# {'a_blum_', 'blum_a_', 'avrim_blum_'}
# {'schapire_r_e_', 'shapire_r_', 'r_schapire_', 'schapire_', 'robert_schapire_', 'r_', 'robert_e_schapire_', 'schapire_r_', 'schapire_robert_e_', 'shapire_r_e_', 'r_e_schapire_'}
# {'n_cesa_bianchi_', 'cesa_bianchi_n_', 'nicolo_cesa_bianchi_'}
# {'goldman_s_', 's_a_goldman_', 'goldman_s_a_', 'sally_a_goldman_', 's_goldman_'}
# {'kautz_henry_'}
# {'d_p_helmbold_', 'david_p_helmhold_', 'david_p_helmbold_', 'helmbold_d_p_', 'd_helmbold_'}
# {'p_auer_'}
# {'r_l_rivest_', 'rivest_ronald_l_', 'rivest_r_l_', 'rivest_r_', 'r_rivest_', 'ronald_l_rivest_'}
# {'littlestone_n_'}
# {'freud_y_', 'yoav_freund_', 'freund_y_', 'freund_v_', 'y_freund_', 'freund_yoav_'}
# {'d_haussler_', 'haussler_david_', 'haussler_d_', 'david_haussler_'}
# {'d_d_lewis_', 'david_d_lewis_', 'lewis_d_d_', 'lewis_d_', 'david_lewis_', 'd_lewis_'}
# {'j_p_kearns_'}
# {'ehrenfeucht_a_', 'ehrenfeucht_andrzej_', 'andrzej_ehrenfeucht_', 'a_ehrenfeucht_'}
# {'eric_bauer_'}
# {'kearns_m_', 'micahel_kearns_', 'kearns_', 'm_j_kearns_', 'michael_j_kearns_', 'michael_kearns_', 'm_kearns_', 'kearns_m_j_', 'kearns_michael_'}
# {'drucker_', 'harris_drucker_', 'drucker_harris_', 'h_druker_', 'drucker_h_', 'h_drucker_'}
# {'t_g_dietterich_', 'dietterich_t_', 't_dietterich_', 'tom_dietterich_', 'dietterich_t_g_'}
# {'m_feder_'}
# {'henry_kautz_', 'kautz_henry_a_', 'h_a_kautz_', 'kautz_h_', 'henry_a_kautz_', 'h_kautz_', 'kautz_h_a_'}
# {'william_w_cohen_', 'w_w_cohen_'}

# %%
uf_venues = UnionFind.UnionFind()
with open(wdir+'/SameVenue.txt') as f:
    for line in f:
        name1, name2 = line.strip().split(',')
        uf_venues.union(name1,name2)
        
print("Number of venues: %d" % len(list(uf_venues.getDisjointSets())))
uf_venues.printDisjointSets()
# Ok, this looks better. Promised 103, got 117... Perhaps there are some sets that need merging within these
# Several of these don't make a lot of sense though. 
# Also, how are there singleton sets, given pairs in the file? Checked: some pairs repeat an element twice :/
# Out:
# Number of venues: 117
#
# Disjoint sets:
# {'an_extended_abstract_appeared_proceedings_30th_symposium_foundations_computer_science_'}
# {'to_appear_proceedings_eleventh_conference_computational_learning_theory_'}
# {'technical_report_ucsc_crl_94_33_'}
# {'inform_comput_', 'inf_computation_', 'information_computation_', 'information_control_', 'information_compuation_'}
# {'preprint_'}
# {'proc_thirteenth_international_conference_machine_learning_', 'proc_13th_int_conf_machine_learning_', 'proc_thirteenth_conf_machine_learning_', 'machine_learning_proceedings_thirteenth_international_conference_', 'proc_thirteenth_international_conference_machine_learning_pp_', 'machine_learning_proceedings_13th_international_conference_', 'proceedings_thirteenth_international_conference_machine_learning_', 'proc_thirteenth_intl_conf_machine_learning_pp_', 'proc_13th_international_conference_machine_learning_', 'proceedings_13rd_international_conference_machine_learning_pp_', 'machine_learning_proceedings_thirteenth_national_conference_', 'proceedings_thirteenth_international_conference_machine_learning_icml_96_', 'proc_thirteenth_conf_machine_learning_pp_', 'machine_learning_proc_13th_international_conference_', 'proc_thirteenth_intl_conf_machine_learning_', 'icml_96_', 'to_appear_proceedings_thirteenth_international_conference_machine_learning_', 'proceedings_13th_international_conference_machine_learning_'}
# {'technical_report_number_ucsc_crl_88_06_'}
# {'advances_neural_information_processing_systems_vol_4_', 'proceedings_fifth_conf_neural_informations_processing_systems_'}
# {'journal_41_1_', '41_'}
# {'proc_36th_symposium_foundations_computer_science_'}
# {'j_computer_system_sciences_'}
# {'unpublished_', 'unpublished_manuscript_'}
# {'machine_learning_from_theory_to_applications_'}
# {'workshop_computational_learning_theory_', 'computational_learning_theory_'}
# {'machine_learning_5_', 'machine_learning_5_2_'}
# {'jcss_48_3_', 'journal_computer_system_sciences_48_'}
# {'sigir_96_proc_19th_int_conference_research_development_information_retrieval_', 'proceedings_sigir_96_', 'proceedings_nineteenth_international_sigir_conference_research_development_information_retrieval_pp_', 'proceedings_nineteenth_international_sigir_conference_research_development_information_retrieval_', 'proc_19th_int_sigir_conf_', 'proceedings_19_th_international_sigir_conference_research_development_information_retrieval_', 'sigir_96_', 'proc_19th_international_sigir_conference_research_development_information_retrieval_', 'proceedings_sigir_1996_', 'sigir_sigir_96_proceedings_19th_international_conference_research_development_information_retrieval_', 'nineteenth_international_sigir_conference_research_development_information_retrieval_'}
# {'journal_computer_system_science_', 'journal_computer_science_system_sciences_', 'journal_computer_systems_sciences_', 'j_comput_syst_sci_', 'journal_computer_system_sciences_'}
# {'eurocolt_'}
# {'machine_learning_28_'}
# {'machine_learning_14_', 'machine_learning_14_1_'}
# {'tech_report_mit_lcs_tm_431_'}
# {'proceedings_winter_simulation_conference_'}
# {'proceedings_sixth_workshop_computational_learning_theory_'}
# {'proceedings_aaai_93_washington_', 'proc_national_conference_artificial_intelligence_1993_', 'proceedings_aaai_1993_', 'proceedings_11th_national_conference_artificial_intelligence_', 'aaai_93_'}
# {'proceedings_11th_international_conference_machine_learning_', 'proc_11th_international_conference_machine_learning_', 'proc_11th_international_conf_machine_learning_', 'machine_learning_proceedings_eleventh_international_conference_', 'proceddings_11th_international_conference_machine_learning_', 'proceedings_eleventh_international_conference_machine_learning_'}
# {'machine_learning_', 'mach_learn_', 'machine_learning_journal_'}
# {'t_t_he_26_th_symposium_heory_computing_', 'proc_26th_sympos_theory_comput_', 'proc_26th_symp_theory_computing_', 'proceedings_twenty_sixth_symposium_theory_computing_', 'proceedings_26th_symposium_theory_computing_', 'proceedings_26_th_symposium_theory_computing_', 'stoc_94_'}
# {'tech_rep_'}
# {'proc_26th_stoc_'}
# {'33_proceedings_1988_workshop_computational_learning_theory_', 'colt_88_proceedings_conference_learning_', 'proceedings_colt_88_', 'proceedings_1988_workshop_computational_learning_theory_', 'proc_1988_workshop_computational_learning_theory_', 'proceedings_first_workshop_computational_learning_theory_morgan_kaufmann_', 'proceedings_first_workshop_computational_learning_theory_'}
# {'jcss_50_1_'}
# {'artificial_intelligence_forthcoming_', 'artificial_intelligence_', 'artif_intell_'}
# {'artificial_intelligence_74_'}
# {'proc_28th_focs_', 'proceedings_twenty_eighth_symposium_foundations_computer_science_', '28th_symposium_foundations_computer_science_', 'proceedings_ieee_symposium_foundations_computer_science_', 'proceedings_28th_foundation_computer_science_ieee_', 'proceeding_twenty_eighth_symposium_foundations_computer_science_', 'proceedings_28th_ieee_symposium_foundations_computer_science_', 'proc_28th_ieee_symp_foundations_computer_science_', 'proceedings_28th_ieee_symp_foundations_computer_science_', 'ieee_symposium_foundations_computer_science_', 'proceedings_focs_87_', 'proceedings_foundations_computer_science_'}
# {'5_'}
# {'proc_national_conference_artificial_intelligence_1992_'}
# {'advances_neural_information_processing_systems_iv_denver_1992_', 'neural_information_processing_systems_4_', 'proceedings_1991_conf_neural_informations_processing_systems_', 'proceedings_1991_conference_neural_information_processing_systems_', 'advances_neural_information_processing_systems_4_', '912919_neural_information_processing_systems_4_edited_by_j_j_moody_s_hanson_r_p_lippmann_'}
# {'crypto_'}
# {'1997_'}
# {'proceedings_1989_workshop_computational_learning_theory_', 'proceedings_second_workshop_computational_learning_theory_'}
# {'institute_mathematics_its_applications_'}
# {'technical_report_mit_lcs_tr_493_'}
# {'proceedings_eleventh_conference_computational_learning_theory_'}
# {'proceedings_29th_symposium_foundations_computer_science_'}
# {'proceedings_24th_symposium_theory_computing_', 'proceedings_24th_symp_theory_computing_'}
# {'siam_j_comput_', 'siam_journal_computing_'}
# {'proceedings_eighteenth_symposium_theory_computing_'}
# {'proceedings_thirty_seventh_symposium_foundations_computer_science_'}
# {'distinguished_dissertation_series_'}
# {'masters_thesis_'}
# {'machine_learning_17_'}
# {'machine_learning_27_'}
# {'pages_433_444_proceedings_21_st_symposium_theory_computing_', 'proceedings_twenty_first_symposium_theory_computing_pp_', '21st_symposium_theory_computing_', 'proceedings_twenty_first_symposium_theory_computing_stoc_89_', 'proceedings_twenty_first_symposium_theoretical_computing_', 'proc_21st_symp_theory_computing_1989_433_444_', 'proceedings_21th_symposium_theory_computing_', 'proc_21st_symp_theoretical_computing_', 'proceedings_21st_symposium_theory_computing_', 'proc_21st_symposium_theory_computing_', 'proc_21st_stpc_', 'proc_21st_symposium_theory_computing_1989_433_444_', 'proceedings_21_st_symposium_theory_computing_', 'proc_21_st_symposium_theory_computing_', 'proceedings_stoc_89_', 'proc_21st_stoc_', 'proc_21_st_stoc_1989_', 'proceedings_21th_symp_theory_computing_', 'proceedings_21th_sympposium_theory_computing_', '34_proceedings_21st_a_c_m_symposium_theory_computing_', 'proceedings_twenty_first_symposium_theory_computing_'}
# {'technical_report_tr_14_88_'}
# {'progress_'}
# {'doctoral_dissertation_', 'phd_thesis_'}
# {'computational_learning_theory_eurocolt_93_volume_new_series_series_number_53_institute_mathematics_its_applications_confer_ence_', 'computational_learning_theory_eurocolt_93_volume_new_series_series_number_53_institute_mathematics_its_applications_conference_', '1993_ima_european_conference_computational_learning_theory_'}
# {'advances_neural_information_processing_systems_volume_5_', 'advances_neural_informations_processing_systems_5_', 'advances_neural_information_processing_systems_5_', 'nips92_p_'}
# {'proceedings_colt_93_'}
# {'international_journal_pattern_recognition_artificial_intelligence_7_4_'}
# {'proc_6th_conf_comput_learning_theory_'}
# {'proceedings_1997_european_conference_computational_learning_theory_', 'proceedings_third_european_conference_computational_learning_theory_eurocolt_97_volume_1208_lecture_notes_computer_science_'}
# {'eurocolt_95_', 'computational_learning_theory_7_second_european_conference_', 'computational_learning_theory_second_european_conference_', 'proceedings_second_european_conference_computational_learning_theory_mar_1995_', 'eurocolt_95_pp_', 'eurocolt95_', 'proc_2nd_european_conf_computational_learning_theory_', 'proceedings_second_european_conference_computational_learning_theory_', 'proceedings_second_european_conference_computational_learning_', '2nd_european_conference_computational_learning_theory_', 'second_european_conference_computational_learning_theory_'}
# {'proceedings_ecml_95_san_francisco_'}
# {'second_european_conference_'}
# {'snowbird_1997_conference_'}
# {'proceedings_1992_conf_neural_informations_processing_systems_to_appear_'}
# {'proceedings_19th_a_c_m_symposium_theory_computing_', 'proceedings_nineteenth_symposium_theory_computing_stoc_87_', 'proc_19th_stoc_', 'proc_19th_symp_theory_computing_', 'proceedings_nineteenth_symposium_theory_computing_', 'stoc_87_p_', 'proc_19th_symposium_theory_computing_1987_285_295_', 'proc_19_th_symposium_theory_computing_', 'proc_19th_sympos_theory_comput_', 'stoc_87_', 'proceedings_nineteenth_symposium_theory_computing_pp_', 'proc_19_th_stoc_', 'proc_19th_symposium_theory_computing_', 'proceedings_19th_symposium_theory_computing_', 'proceedings_19th_symposium_theory_computation_', '19th_symposium_theory_computing_', 'proceedings_19th_symposium_theory_computations_'}
# {'proceedings_thirteenth_conference_uncertainty_artificial_intelligence_1997_', 'proc_13th_conference_uncertainty_artificial_intelligence_', 'proceedings_thirteenth_conference_uncertainty_artificial_intelligence_'}
# {'proceedings_fourth_international_workshop_machine_learning_pp_', 'proceedings_fourth_international_workshop_machine_learning_pat_langley_', 'proceedings_4th_international_workshop_machine_learning_', 'proceedings_fourth_international_workshop_machine_learning_', 'proceedings_fourth_international_conference_machine_learning_ml_87_'}
# {'proceedings_national_conference_artificial_intelligence_', 'proceedings_aaai_'}
# {'technical_report_ucsc_crl_87_26_'}
# {'technical_report_'}
# {'neural_networks_5_'}
# {'manuscript_'}
# {'proceedings_20_th_symposium_theory_computing_', 'proceedings_twentieth_symposium_theory_computing_stoc_88_', '20th_symposium_theory_computing_', 'proceedings_stoc_88_', 'proceedings_twentieth_symposium_theory_computing_chicago_', 'proceedings_twentieth_symposium_theory_computing_', 'proceedings_20th_symposium_theory_computing_chicago_1988_', 'proc_20th_sympos_theory_comput_', 'proceedings_20th_symposium_theory_computation_', 'proceedings_20th_a_c_m_symposium_theory_computing_'}
# {'proceedings_30th_symposium_foundation_computer_science_', '30th_symposium_foundations_computer_science_', 'proceedings_30th_symposium_foundations_computer_science_', 'proceedings_thirtieth_symposium_foundations_computer_science_'}
# {'proceedings_24th_symposium_theory_computing_stoc_'}
# {'advances_neural_information_processing_8_', 'advances_neural_information_processing_systems_8_', 'advances_neural_information_processing_systems_number_8_nips_'}
# {'formation_computation_103_2_1993_', 'information_computation_103_', 'information_computation_103_2_'}
# {'proceedings_twenty_ninth_symposium_theory_computing_', 'proceedings_twentyninth_symposium_theory_computing_'}
# {'proceedings_sigir_conference_', 'proceedings_sigir_', 'proceeding_sigir_'}
# {'proc_ieee_information_theory_conference_'}
# {'symp_theory_computing_', 'symposium_theory_computing_', 'proc_symposium_theory_computing_', 'stoc_p_', 'proceedings_symposium_theory_computing_pp_', 'stoc_', 'proceedings_symp_theory_computing_'}
# {'chp_'}
# {'31st_symposium_foundations_computer_science_', 'proceedings_31st_symposium_foundation_computer_science_', 'proceedings_31st_symposium_foundations_computer_science_', 'proc_31st_symposium_foundations_comp_sci_', 'proceedings_31st_symposium_foundations_computer_science_pp_', 'proceedings_focs_90_', 'proceedings_thirty_first_symposium_founda_tions_computer_science_', '31st_symposium_foundations_computer_science_pp_', 'focs_90_', 'proceedings_thirty_first_symposium_foundations_computer_science_', 'proceedings_thirty_first_ieee_symposium_foundations_computer_science_focs_90_', 'proceedings_31st_ieee_symposium_foundations_computer_science_october_1990_'}
# {'advances_neural_information_processing_systems_10_'}
# {'neural_information_processing_systems_12_'}
# {'proc_25th_sympos_theory_comput_1993_', 'proc_25_th_symposium_theory_computing_', 'proc_25th_sympos_theory_comput_', 'stoc_93_', '25th_symposium_theory_computing_to_appear_', '25th_stoc_', 'proc_stoc_93_', 'proc_25th_symp_theory_computing_', 'proc_25th_stoc_', 'proceedings_twenty_fifth_symposium_theory_computing_stoc_93_', 'computer_research_laboratory_an_extended_abstract_appeared_proceedings_25th_symposium_theory_computing_', '13_proceedings_25th_symposium_theory_com_puting_', 'proceedings_25th_symposium_theory_computing_pp_', '25th_symposium_theory_computing_', '25th_symposium_theory_computing_1994_', 'proceedings_25_th_symposium_theory_computing_', 'proceedings_25th_symp_theory_computing_', 'proc_25th_sym_pos_theory_comput_', 'proc_25th_symp_theory_computing_1993_', 'proceedings_25th_symposium_theory_computation_', 'proceedings_25th_symposium_theory_computing_', 'proceedings_43_twenty_fifth_symposium_theory_computing_', 'proceedings_twenty_fifth_symposium_theory_computing_', '25th_symp_theory_computing_', 'proc_25th_symposium_theory_computing_', 'proceedings_stoc93_'}
# {'technical_report_ucsc_crl_95_50_'}
# {'international_journal_pattern_recognition_artificial_intelligence_', 'intl_j_pat_recog_art_intel_'}
# {'technical_report_mit_lcs_tm_413_'}
# {'proceedings_colt_95_', 'proceedings_eighth_conference_computational_learning_theory_colt_', 'proceedings_8th_conference_computational_learning_theory_', 'proceedings_eighth_workshop_computational_learning_theory_', 'proceedings_eighth_conference_computational_learning_theory_', 'to_appear_proceedings_eighth_conference_computational_learning_theory_', 'appearing_proc_eighth_conf_computational_learning_theory_', 'proceedings_1995_conference_computational_learning_theory_', 'proceedingsof_eighth_workshop_computationallearning_theory_', 'colt_95_', 'proceedings_eigth_conference_computational_learning_theory_'}
# {'proceedings_5th_workshop_computational_learning_theory_', 'proc_5th_workshop_comput_learning_theory_', 'proceedings_fifth_workshop_computational_learning_theory_colt_92_', 'proceedings_fifth_workshop_computational_learning_theory_pp_', '5th_colt_', 'proceedings_fifth_workshop_computational_learning_theory_', 'proceedings_fifth_workshop_computational_learning_theory_1992_', 'proc_5th_workshop_computational_learning_theory_', '5th_workshop_computational_learning_theory_1992_341_352_', 'fifth_workshop_computational_learning_theory_', 'proceedings_colt_92_', 'proceedings_5rd_workshop_computational_learning_theory_', 'proc_5th_work_comp_learning_theory_pp_', 'proc_5th_conference_computational_learning_theory_1992_341_352_', 'proc_5th_workshop_computational_learning_theory_1992_'}
# {'ietf_'}
# {'an_extended_abstract_appeared_proceedings_1st_workshop_computational_learning_theory_'}
# {'advances_neural_information_processing_systems_', 'neural_information_processing_systems_'}
# {'42_proceedings_30th_i_e_e_e_symposium_foundations_computer_science_', 'proceedings_30th_i_e_e_e_symposium_foundations_computer_science_'}
# {'information_computation_121_2_'}
# {'proceedings_fourteenth_international_conference_machine_learning_', 'icml_97_', 'machine_learning_proceedings_fourteenth_international_conference_icml_97_', 'proceedings_14th_international_conference_machine_learning_', 'machine_learning_proceedings_fourteenth_international_conference_'}
# {'information_computation_82_', 'information_control_82_'}
# {'57_62_'}
# {'proceedings_9th_conference_computational_learning_theory_', 'pro_ceedings_9th_conference_computational_learning_theory_', 'proc_9th_conference_computational_learning_theory_', 'proceedings_ninth_conference_computational_learning_theory_', 'colt_96_'}
# {'pre_proceedings_crypto_93_', 'proc_crypto_93_'}
# {'lecture_notes_artificial_intelligence_'}
# {'annals_statistics_'}
# {'proc_forth_workshop_computational_learning_theory_', 'proceedings_fourth_workshop_computational_learning_theory_', 'computational_learning_theory_proceedings_fourth_workshop_', 'colt_91_proceedings_4th_workshop_computational_learning_theory_', 'proceedings_fourth_workshop_computational_learning_theory_pages_61_74_', 'proc_4th_workshop_comput_learning_theory_', 'proceedings_fourth_conference_computational_learning_theory_colt_91_', 'proceedings_fourth_workshop_computational_learning_theory_pp_', '1991_workshop_computational_learning_theory_', 'proceedings_4th_workshop_computational_learning_theory_', 'computation_learning_theory_proceedings_fourth_workshop_', 'proc_fourth_workshop_computational_learning_theory_', 'proceedings_1991_workshop_computational_learning_theory_', 'colt_91_', 'proc_4th_workshop_computational_learning_theory_'}
# {'proc_workshop_computational_learning_theory_'}
# {'proceedings_twenty_eighth_symposium_theory_computing_', 'to_appear_proceedings_28th_symposium_theory_computing_', 'proceedings_28th_symposium_theory_computing_'}
# {'journal_computer_system_sciences_55_1_'}
# {'proceedings_international_conference_machine_learning_san_francisco_', 'machine_learning_proceedings_international_conference_', 'proceedings_international_conference_machine_learning_'}
# {'proc_3rd_work_comp_learning_theory_pp_', 'proc_3rd_workshop_comput_learning_theory_', 'proceedings_1990_workshop_computational_learning_theory_p_', 'proceedings_1990_workshop_computational_learning_theory_', 'proceedings_colt_90_', '3rd_workshop_computational_learning_theory_', 'proc_3rd_work_comp_learning_theory_', 'proceedings_third_workshop_computational_learning_theory_pp_', 'proceedings_third_workshop_computational_learning_theory_', 'proceedings_3rd_workshop_computational_learning_theory_'}
# {'j_assoc_computing_mach_', 'journal_association_computing_machinery_', 'journal_', 'j_'}
# {'proceedings_seventh_workshop_computational_learning_theory_', 'proceedings_colt_1994_', 'proc_7th_conference_computational_learning_theory_1994_1994_press_', 'proceedings_7th_workshop_computational_learning_theory_', 'proceedings_seventh_confernce_computational_learning_theory_', 'proc_7th_workshop_comput_learning_theory_', 'colt_1994_', 'proceedings_seventh_workshop_computational_learning_theory_colt_94_', 'proceedings_seventh_conference_computational_learning_theory_colt_94_', 'proceedings_seventh_conference_computational_learning_theory_'}
# {'proceedings_36_th_symposium_foundations_computer_science_', 'focs_36_', 'to_appear_proceedings_thirty_sixth_symposium_foundations_computer_science_', 'proceedings_thirty_sixth_symposium_foundations_computer_science_'}
# {'proceedings_tenth_conference_computational_learning_theory_'}

# %%
df[['author','class_no']]
## Applying the following transformation
## 1. remove ' and '
## 2. remove &
## 3. split by ','
authors = df[['author','class_no']]['author'].str.replace(' and ','').str.replace('&','').str.split(',')

# %%
authors_with_class = pd.DataFrame({'class_no':df['class_no'],'extracted_author_string':df['author'],'author_list':authors})

# %%
authors_with_class
# Out:
#                                             author_list        class_no  \
# 0                [h. drucker,  r. schapire, p. simard.]     drucker1992
# 1                [h. drucker,  r. schapire, p. simard.]     drucker1992
# 2               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 3               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 4               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 5               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 6                 [drucker h.,  schapire r., simard p.]     drucker1992
# 7                 [drucker h.,  schapire r., simard r.]     drucker1992
# 8     [drucker harris,  schapire,  robert, simard pa...     drucker1992
# 9                [drucker h.,  schapire r.,  simard p.]     drucker1992
# 10                         [drucker,  schapire, simard]     drucker1992
# 11    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 12    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 13                [h. drucker,  r. schapire, p. simard]     drucker1992
# 14               [drucker h.,  schapire r.,  simard p.]     drucker1992
# 15    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 16    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 17    [harris drucker,  robert e. schapire, ptrice s...     drucker1992
# 18                [h. druker,  r. schapire,  p. simard]     drucker1992
# 19                     [drucker h.,  r. schapire,   p.]     drucker1992
# 20              [drucker h.,  schapire r.,   simard p.]     drucker1992
# 21                                      [r.,   hart p.]   drucker1992C1
# 22                   [yoav freund, robert e. schapire.]     freund0000a
# 23                   [yoav freund, robert e. schapire.]     freund0000a
# 24    [y. freund,  h. s. seung,  e. shamir, n. tishby.]     freund1992a
# 25    [yoav freund,  h. sebastian seung,  eli shamir...     freund1992a
# 26    [freund y.,  seung h. s.,  shamir e.,   tishby...     freund1992a
# 27      [freund y.,  seung h.,  shamir e.,   tishby n.]     freund1992a
# 28        [freund y.,  seung h.,  shamir e., tishby n.]     freund1992a
# 29      [freund y.,  seung h.s.,  shamir e., tishby n.]     freund1992a
# ...                                                 ...             ...
# 1265                                  [r. e. schapire.]    schapire1991
# 1266                              [robert e. schapire.]    schapire1991
# 1267                                    [schapire r.e.]    schapire1991
# 1268                                    [schapire r.e.]    schapire1991
# 1269                              [robert e. schapire.]  schapire1991C1
# 1270                              [robert e. schapire.]   schapire1991l
# 1271                              [robert e. schapire.]   schapire1991l
# 1272                                  [r. e. schapire.]    schapire1992
# 1273                   [r. e. schapire,  l. m. sellie.]    schapire1993
# 1274  [schapire r.e.,  freund y.,  bartlett p.,  lee...    schapire1997
# 1275  [r. e. schapire,  y. freund,  p. bartlett, w. ...    schapire1997
# 1276  [schapire r. e.,  freund y.,  bartlett p.,   l...    schapire1997
# 1277  [schapire r. e.,  freund y.,  bartlett p.,   l...    schapire1997
# 1278    [schapire r.,  freund y.,  bartlett p., lee w.]    schapire1997
# 1279        [schapire r.,  y. freund,  p. bartlett, w.]    schapire1997
# 1280  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1281  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1282  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1283  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1284                   [schapire r.e.,  y. freund,  p.]    schapire1997
# 1285   [shapire r.,  freund y.,  bartlett p.,   lee w.]    schapire1997
# 1286  [r. schapire,  y. freund,  p. bartlett, w. s. ...    schapire1997
# 1287  [schapire r. e.,  freund y.,  bartlett p.,   l...    schapire1997
# 1288  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1289  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1290  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1291  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1292          [r.e. schapire,  y. freund,  p. bartlett]    schapire1997
# 1293   [r. schapire,  y. freund,  p. bartlett, w. lee.]    schapire1997
# 1294   [schapire,  r.e.,  freund y.,  bartlett p., lee]    schapire1997
#
#                                 extracted_author_string
# 0               h. drucker, r. schapire, and p. simard.
# 1               h. drucker, r. schapire, and p. simard.
# 2                  drucker h., schapire r., & simard p.
# 3                  drucker h., schapire r., & simard p.
# 4                  drucker h., schapire r., & simard p.
# 5                  drucker h., schapire r., & simard p.
# 6                drucker h., schapire r., and simard p.
# 7                drucker h., schapire r., and simard r.
# 8     drucker harris, schapire, robert, and simard p...
# 9                    drucker h., schapire r., simard p.
# 10                        drucker, schapire, and simard
# 11    harris drucker, robert schapire, and patrice s...
# 12    harris drucker, robert schapire, and patrice s...
# 13               h. drucker, r. schapire, and p. simard
# 14                   drucker h., schapire r., simard p.
# 15    harris drucker, robert schapire, and patrice s...
# 16    harris drucker, robert schapire, and patrice s...
# 17    harris drucker, robert e. schapire, and ptrice...
# 18                    h. druker, r. schapire, p. simard
# 19                        drucker h., r. schapire, & p.
# 20                 drucker h., schapire r., & simard p.
# 21                                        r., & hart p.
# 22                 yoav freund, and robert e. schapire.
# 23                 yoav freund, and robert e. schapire.
# 24    y. freund, h. s. seung, e. shamir, and n. tishby.
# 25    yoav freund, h. sebastian seung, eli shamir, a...
# 26       freund y., seung h. s., shamir e., & tishby n.
# 27          freund y., seung h., shamir e., & tishby n.
# 28        freund y., seung h., shamir e., and tishby n.
# 29      freund y., seung h.s., shamir e., and tishby n.
# ...                                                 ...
# 1265                                    r. e. schapire.
# 1266                                robert e. schapire.
# 1267                                      schapire r.e.
# 1268                                      schapire r.e.
# 1269                                robert e. schapire.
# 1270                                robert e. schapire.
# 1271                                robert e. schapire.
# 1272                                    r. e. schapire.
# 1273                      r. e. schapire, l. m. sellie.
# 1274    schapire r.e., freund y., bartlett p., lee w.s.
# 1275  r. e. schapire, y. freund, p. bartlett, and w....
# 1276  schapire r. e., freund y., bartlett p., & lee ...
# 1277  schapire r. e., freund y., bartlett p., & lee ...
# 1278    schapire r., freund y., bartlett p., and lee w.
# 1279        schapire r., y. freund, p. bartlett, and w.
# 1280  schapire r.e., freund y., bartlett p., and lee...
# 1281  schapire r.e., freund y., bartlett p., and lee...
# 1282  schapire r.e., freund y., bartlett p., and lee...
# 1283  schapire r.e., freund y., bartlett p., and lee...
# 1284                       schapire r.e., y. freund, p.
# 1285       shapire r., freund y., bartlett p., & lee w.
# 1286  r. schapire, y. freund, p. bartlett, and w. s....
# 1287  schapire r. e., freund y., bartlett p., & lee ...
# 1288  robert e. schapire, yoav freund, peter bartlet...
# 1289  robert e. schapire, yoav freund, peter bartlet...
# 1290  robert e. schapire, yoav freund, peter bartlet...
# 1291  robert e. schapire, yoav freund, peter bartlet...
# 1292              r.e. schapire, y. freund, p. bartlett
# 1293   r. schapire, y. freund, p. bartlett, and w. lee.
# 1294    schapire, r.e., freund y., bartlett p., and lee
#
# [1295 rows x 3 columns]

# %%
titles_with_class = df[['class_no','title']]
titles_with_class
# Out:
#             class_no                                              title
# 0        drucker1992   improving performance in neural networks usin...
# 1        drucker1992   improving performance in neural networks usin...
# 2        drucker1992   improving performance in neural networks usin...
# 3        drucker1992   improving performance in neural networks usin...
# 4        drucker1992   improving performance in neural networks usin...
# 5        drucker1992   improving the performance in neural networks ...
# 6        drucker1992   improving performance in neural networks usin...
# 7        drucker1992   improving performance in neural networks usin...
# 8        drucker1992  improving performance in neural networks using...
# 9        drucker1992  'improving performance in neural networks usin...
# 10       drucker1992   improving performance in neural networks usin...
# 11       drucker1992   improving performance in neural networks usin...
# 12       drucker1992   improving performance in neural networks usin...
# 13       drucker1992   'improving performance in neural networks usi...
# 14       drucker1992  'improving performance in neural networks usin...
# 15       drucker1992   improving performance in neural networks usin...
# 16       drucker1992   improving performance in neural networks usin...
# 17       drucker1992   improving performance in neural networks usin...
# 18       drucker1992   improving performance in neural networks usin...
# 19       drucker1992   improving the performance in neural networks ...
# 20       drucker1992   improving performance in neural networks usin...
# 21     drucker1992C1         pattern classification and scene analysis.
# 22       freund0000a   adaptive game playing using multiplicative we...
# 23       freund0000a   adaptive game playing using multiplicative we...
# 24       freund1992a   information, prediction, and query by committee.
# 25       freund1992a   information, prediction, and query by committee.
# 26       freund1992a   information, prediction, and query by committee.
# 27       freund1992a   information, prediction, and query by committee,
# 28       freund1992a     information, prediction and query by comittee.
# 29       freund1992a   information, prediction, and query by committee.
# ...              ...                                                ...
# 1265    schapire1991   the design and analysis of efficient learning...
# 1266    schapire1991   the design and analysis of efficient learning...
# 1267    schapire1991   the design and analysis of efficient learning...
# 1268    schapire1991   the design and analysis of efficient learning...
# 1269  schapire1991C1   the design and analysis of efficient learning...
# 1270   schapire1991l   learning probabilistic read-once formulas on ...
# 1271   schapire1991l   learning probabilistic read-once formulas on ...
# 1272    schapire1992   the design and analysis of ef ficient learnin...
# 1273    schapire1993   learning sparse multivariate polynomial over ...
# 1274    schapire1997   boosting the margin: a new explanation for th...
# 1275    schapire1997   boosting the margin: a new explanation for th...
# 1276    schapire1997   boosting the margin: a new explanation for th...
# 1277    schapire1997   boosting the margin: a new explanation for th...
# 1278    schapire1997   boosting the margin: a new explanation for th...
# 1279    schapire1997   lee (1997). boosting the margin : a new expla...
# 1280    schapire1997   boosting the margin: a new explanation for th...
# 1281    schapire1997  : boosting the margin: a new explanation for t...
# 1282    schapire1997                               boosting the margin:
# 1283    schapire1997   boosting the margin: a new explanation for th...
# 1284    schapire1997   bartlett & w.s. lee (1997), boosting the marg...
# 1285    schapire1997   boosting the margin: a new explanation for th...
# 1286    schapire1997   boosting the margin; a new explanation for th...
# 1287    schapire1997   boosting the margin: a new explanation for th...
# 1288    schapire1997   boosting the margin: a new explanation for th...
# 1289    schapire1997   boosting the margin: a new explanation for th...
# 1290    schapire1997   boosting the margin: a new explanation for th...
# 1291    schapire1997   boosting the margin: a new explanation for th...
# 1292    schapire1997   and w.s. leee. boosting the margin: a new exp...
# 1293    schapire1997   boosting the margin: a new explanation for th...
# 1294    schapire1997   w.s. boosting the margin: a new explanation f...
#
# [1295 rows x 2 columns]

# %%
# So, taking stock of the situation, we have 1295 records, each is a citation: a mention of a publication
# The citation refers to the same underlying entity, the publication
# Perhaps we can think of the publication as the (not so) latent entity, whose attributes we are trying to resolve.
# We are trying to resolve the authors, and titles. 
# There are several authors mentions per publication mention, and one title mention per 
# So, we must create predicates for:
# a) The titles  - The ground truth for title1 == title2 is class_no1 == class_no2
# b) The authors - This is trickier. We don't have the ground truth for this explicitly.
# So we attempt to derive it from the authors_with_class dataframe.

# %%
#First, let's at least get a complete list of authors:
authors_set = set()
for index, row in authors_with_class.iterrows():
    for author in row['author_list']:
        authors_set.add(author.strip())
print(len(authors_set))
#print(authors_set)
# Out:
# 326

# %%
# Looks alright. We need to keep a list of references to the citations. The row index in our case.
authors_set = set()
for index, row in authors_with_class.iterrows():
    for author in row['author_list']:
        authors_set.add((index, author.strip()))
len(authors_set)
# Out:
# 3524

# %%
# Since we will use year to standard block:
years = df[['class_no','year']]
#But looks like it could use some cleaning up
years['year'] = years['year'].str.replace(r'\D+', '').astype('int')
# Out:
# /soe/nkini/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
years
# Out:
#             class_no  year
# 0        drucker1992  1993
# 1        drucker1992  1993
# 2        drucker1992  1992
# 3        drucker1992  1992
# 4        drucker1992  1993
# 5        drucker1992  1993
# 6        drucker1992  1993
# 7        drucker1992  1993
# 8        drucker1992  1993
# 9        drucker1992  1993
# 10       drucker1992  1993
# 11       drucker1992  1993
# 12       drucker1992  1992
# 13       drucker1992  1993
# 14       drucker1992  1993
# 15       drucker1992  1993
# 16       drucker1992  1993
# 17       drucker1992  1993
# 18       drucker1992  1993
# 19       drucker1992  1993
# 20       drucker1992  1993
# 21     drucker1992C1  1973
# 22       freund0000a     0
# 23       freund0000a     0
# 24       freund1992a  1993
# 25       freund1992a  1993
# 26       freund1992a  1993
# 27       freund1992a  1993
# 28       freund1992a  1993
# 29       freund1992a  1992
# ...              ...   ...
# 1265    schapire1991  1992
# 1266    schapire1991  1991
# 1267    schapire1991  1992
# 1268    schapire1991  1992
# 1269  schapire1991C1  1991
# 1270   schapire1991l  1991
# 1271   schapire1991l  1991
# 1272    schapire1992  1992
# 1273    schapire1993  1993
# 1274    schapire1997  1997
# 1275    schapire1997  1997
# 1276    schapire1997  1997
# 1277    schapire1997  1997
# 1278    schapire1997  1997
# 1279    schapire1997  1997
# 1280    schapire1997  1997
# 1281    schapire1997  1997
# 1282    schapire1997  1997
# 1283    schapire1997  1997
# 1284    schapire1997  1997
# 1285    schapire1997  1997
# 1286    schapire1997  1997
# 1287    schapire1997  1997
# 1288    schapire1997  1997
# 1289    schapire1997  1997
# 1290    schapire1997  1997
# 1291    schapire1997  1997
# 1292    schapire1997  1997
# 1293    schapire1997  1997
# 1294    schapire1997  1997
#
# [1295 rows x 2 columns]

# %%
'''
Do we have everything we need now? Let's see:
R1: SIMTITLE(P1,P2) ⇒ SAMEPUB(P1,P2)
R2: SAMEAUTHOR(P1,P2) ⇒ SAMEPUB(P1,P2)
R3: SIMNAME(A1,A2) ⇒ SAMEAUTHOR(A1,A2)
R4: COAUTHORS(A1,A2)∧COAUTHORS(A2,A3) ⇒ SAMEAUTHOR(A1,A3)
R5: SAMEAUTHOR(A1,A2)∧SAMEAUTHOR(A2,A3) ⇒SAMEAUTHOR(A1,A3)

I see several problems already.

SAMEAUTHOR(P1,P2) vs SAMEAUTHOR(A1,A2). 
What I wanted to say was haveSameAuthors(P1, P2), not SAMEAUTHOR(P1,P2)

Well, how would you say haveSameAuthors(P1, P2)?
SameAuthors(P1,+A)  -> haveSameAuthors(P1, P2), maybe?

Secondly, rule two seems to be wrong, outright. Having the same authors makes the publication the same? 
Of course not.

There needs to be a predicate tying an author and the publication/citation, no?

This seems a better way to write the model:
// If two publications have similar titles, they are likely the same publication
haveSimTitle(P1,P2) ⇒ SamePub(P1,P2)

// If two publications have similar author strings, they are likely the same publication
haveSimAuthors(P1,P2) ⇒ SamePub(P1,P2)

// If two publications are the same, they must have the same authors
hasAuthor(P1, A1) ^ hasAuthor(P2, A2) ^ SamePub(P1,P2) ^ haveSimilarNames(A1, A2) -> SameAuthor(A1, A2)

// If two publications are the same, their authors must be the same
hasAuthor(P1, A1) ^ hasAuthor(P2, A2) ^ SamePub(P1,P2) ^ haveSimilarNames(A1, A2) -> SameAuthor(A1, A2)

// The Co-occurrence rule: If authors who are known to be the same occur with unresolved authors with similar names,
//     the unresolved authors are likely the SameAuthor
areCoAuthors(A1, A2) ^ areCoAuthors(A3, A4) ^ SameAuthor(A1, A3) -> SameAuthor(A2, A4)

// The transitivity rule
SameAuthor(A1, A2) ^ SameAuthor(A2, A3) -> SameAuthor(A1, A3)

Can we come up with some negative rules?

areCoAuthors -> !SameAuthor
haveDissimilarNames -> !SameAuthor
haveDissimilarTitles -> !SamePub

Notes:
It seems wrong to say that if two publications aren't the same,
then the cross product of the authors of the two publications aren't the same...

Well, come to think of it, it seems wrong to use similar name to say the authors are the same
    because entity disambiguation :/
'''
'''
So, the list of predicates we want is:
Blocking:
Block

Obs:
haveSimTitle
hasAuthor
haveSimilarNames
haveSimilarAuthors
areCoAuthors

Targets and GroundTruth:
SamePub
SameAuthor
'''
print("Continued below...")
# Out:
# Continued below...

# %%
df
# Out:
#                       address  \
# 0                         NaN
# 1                         NaN
# 2              san francisco:
# 3              palo alto, ca.
# 4              san mateo, ca.
# 5                         NaN
# 6                         NaN
# 7              san mateo, ca.
# 8             san ma-teo, ca.
# 9                      42-49,
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13             san mateo, ca,
# 14                     42-49,
# 15                        NaN
# 16       san mateo, ca, 1993.
# 17       san mateo, ca, 1993.
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24       san mateo, ca, 1992.
# 25             san mateo, ca,
# 26             san mateo, ca.
# 27     san mateo, california.
# 28             san mateo, ca.
# 29             san mateo, ca.
# ...                       ...
# 1265           cambridge, ma,
# 1266                      NaN
# 1267                      NaN
# 1268                      NaN
# 1269                      NaN
# 1270                      NaN
# 1271                      NaN
# 1272          cam bridge, ma,
# 1273                      NaN
# 1274                      NaN
# 1275                      NaN
# 1276                      NaN
# 1277                      NaN
# 1278                      NaN
# 1279                      NaN
# 1280                      NaN
# 1281                      NaN
# 1282                      NaN
# 1283                      NaN
# 1284                      NaN
# 1285                      NaN
# 1286                      NaN
# 1287                      NaN
# 1288                      NaN
# 1289                      NaN
# 1290                      NaN
# 1291                      NaN
# 1292                      NaN
# 1293                      NaN
# 1294                      NaN
#
#                                                  author bib_no  \
# 0               h. drucker, r. schapire, and p. simard.   0001
# 1               h. drucker, r. schapire, and p. simard.   0002
# 2                  drucker h., schapire r., & simard p.   0003
# 3                  drucker h., schapire r., & simard p.   0004
# 4                  drucker h., schapire r., & simard p.   0005
# 5                  drucker h., schapire r., & simard p.   0006
# 6                drucker h., schapire r., and simard p.   0007
# 7                drucker h., schapire r., and simard r.   0008
# 8     drucker harris, schapire, robert, and simard p...   0009
# 9                    drucker h., schapire r., simard p.   0010
# 10                        drucker, schapire, and simard   0011
# 11    harris drucker, robert schapire, and patrice s...   0012
# 12    harris drucker, robert schapire, and patrice s...   0013
# 13               h. drucker, r. schapire, and p. simard   0014
# 14                   drucker h., schapire r., simard p.   0015
# 15    harris drucker, robert schapire, and patrice s...   0016
# 16    harris drucker, robert schapire, and patrice s...   0017
# 17    harris drucker, robert e. schapire, and ptrice...   0018
# 18                    h. druker, r. schapire, p. simard   0019
# 19                        drucker h., r. schapire, & p.   0020
# 20                 drucker h., schapire r., & simard p.   0021
# 21                                        r., & hart p.   0022
# 22                 yoav freund, and robert e. schapire.   0023
# 23                 yoav freund, and robert e. schapire.   0024
# 24    y. freund, h. s. seung, e. shamir, and n. tishby.   0025
# 25    yoav freund, h. sebastian seung, eli shamir, a...   0026
# 26       freund y., seung h. s., shamir e., & tishby n.   0027
# 27          freund y., seung h., shamir e., & tishby n.   0028
# 28        freund y., seung h., shamir e., and tishby n.   0029
# 29      freund y., seung h.s., shamir e., and tishby n.   0030
# ...                                                 ...    ...
# 1265                                    r. e. schapire.   2418
# 1266                                robert e. schapire.   2419
# 1267                                      schapire r.e.   2420
# 1268                                      schapire r.e.   2421
# 1269                                robert e. schapire.   2422
# 1270                                robert e. schapire.   2423
# 1271                                robert e. schapire.   2424
# 1272                                    r. e. schapire.   2425
# 1273                      r. e. schapire, l. m. sellie.   2426
# 1274    schapire r.e., freund y., bartlett p., lee w.s.   2427
# 1275  r. e. schapire, y. freund, p. bartlett, and w....   2428
# 1276  schapire r. e., freund y., bartlett p., & lee ...   2429
# 1277  schapire r. e., freund y., bartlett p., & lee ...   2430
# 1278    schapire r., freund y., bartlett p., and lee w.   2431
# 1279        schapire r., y. freund, p. bartlett, and w.   2432
# 1280  schapire r.e., freund y., bartlett p., and lee...   2433
# 1281  schapire r.e., freund y., bartlett p., and lee...   2434
# 1282  schapire r.e., freund y., bartlett p., and lee...   2435
# 1283  schapire r.e., freund y., bartlett p., and lee...   2436
# 1284                       schapire r.e., y. freund, p.   2437
# 1285       shapire r., freund y., bartlett p., & lee w.   2438
# 1286  r. schapire, y. freund, p. bartlett, and w. s....   2439
# 1287  schapire r. e., freund y., bartlett p., & lee ...   2440
# 1288  robert e. schapire, yoav freund, peter bartlet...   2441
# 1289  robert e. schapire, yoav freund, peter bartlet...   2442
# 1290  robert e. schapire, yoav freund, peter bartlet...   2443
# 1291  robert e. schapire, yoav freund, peter bartlet...   2444
# 1292              r.e. schapire, y. freund, p. bartlett   2445
# 1293   r. schapire, y. freund, p. bartlett, and w. lee.   2446
# 1294    schapire, r.e., freund y., bartlett p., and lee   2447
#
#             class_no                                             editor  \
# 0        drucker1992   in steven j. hanson, jack d. cowan, and c. le...
# 1        drucker1992   in steven j. hanson, jack d. cowan, and c. le...
# 2        drucker1992                                                NaN
# 3        drucker1992    in hanson, j., cowan, j., & giles, c., editors,
# 4        drucker1992   in hanson, s. j., cowan, j. d., & giles, c. l...
# 5        drucker1992                                                NaN
# 6        drucker1992   in hanson, s. j., cowan, j. d., and giles, c....
# 7        drucker1992   in hanson, s. j., cowan, j. d., and giles, c....
# 8        drucker1992                                                NaN
# 9        drucker1992           s. j. hanson, j. cowan, l. giles (eds.),
# 10       drucker1992                                                NaN
# 11       drucker1992   in steven j. hanson, jack d. cowan, and c. le...
# 12       drucker1992                                                NaN
# 13       drucker1992   s. j. han-son, j. d. cowan, and c. l. giles, ...
# 14       drucker1992           s. j. hanson, j. cowan, l. giles (eds.),
# 15       drucker1992                                                NaN
# 16       drucker1992                                                NaN
# 17       drucker1992                                                NaN
# 18       drucker1992                                                NaN
# 19       drucker1992                                                NaN
# 20       drucker1992            in s. hanson, j. cowan & c. giles, eds,
# 21     drucker1992C1   in hanson, s. j., cowan, j. d., & giles, c. l...
# 22       freund0000a                                                NaN
# 23       freund0000a                                                NaN
# 24       freund1992a                                                NaN
# 25       freund1992a   in stephen jose hanson, jack d. cowan, and c....
# 26       freund1992a   in hanson, s. j., cowan, j. d., & giles, c. l...
# 27       freund1992a                                                NaN
# 28       freund1992a   in hanson, s. j., cowan, j. d., and giles, c....
# 29       freund1992a                                                NaN
# ...              ...                                                ...
# 1265    schapire1991                                                NaN
# 1266    schapire1991                                                NaN
# 1267    schapire1991                                                NaN
# 1268    schapire1991                                                NaN
# 1269  schapire1991C1                                                NaN
# 1270   schapire1991l                                                NaN
# 1271   schapire1991l                                                NaN
# 1272    schapire1992                                                NaN
# 1273    schapire1993                                                NaN
# 1274    schapire1997                                                NaN
# 1275    schapire1997                                                NaN
# 1276    schapire1997                                 in d. fisher, ed.,
# 1277    schapire1997                                 in d. fisher, ed.,
# 1278    schapire1997                                                NaN
# 1279    schapire1997                                                NaN
# 1280    schapire1997                                                NaN
# 1281    schapire1997                                                NaN
# 1282    schapire1997                                                NaN
# 1283    schapire1997                                                NaN
# 1284    schapire1997                                                NaN
# 1285    schapire1997                                                NaN
# 1286    schapire1997                                                NaN
# 1287    schapire1997                                                NaN
# 1288    schapire1997                                                NaN
# 1289    schapire1997                                                NaN
# 1290    schapire1997                                                NaN
# 1291    schapire1997                                                NaN
# 1292    schapire1997                                                NaN
# 1293    schapire1997                                                NaN
# 1294    schapire1997                                                NaN
#
#                                 institution    month  \
# 0                                       NaN      NaN
# 1                                       NaN      NaN
# 2                                       NaN      NaN
# 3                                       NaN      NaN
# 4                                       NaN      NaN
# 5                                       NaN      NaN
# 6                                       NaN      NaN
# 7                                       NaN      NaN
# 8                                       NaN      NaN
# 9                                       NaN      NaN
# 10                                      NaN      NaN
# 11                                      NaN      NaN
# 12                                      NaN      NaN
# 13                                      NaN      NaN
# 14                                      NaN      NaN
# 15                                      NaN      NaN
# 16                                      NaN      NaN
# 17                                      NaN      NaN
# 18                                      NaN      NaN
# 19                                      NaN    simad
# 20                                      NaN      NaN
# 21                                      NaN      NaN
# 22                                      NaN      NaN
# 23                                      NaN      NaN
# 24                                      NaN      NaN
# 25                                      NaN      NaN
# 26                                      NaN      NaN
# 27                                      NaN      NaN
# 28                                      NaN      NaN
# 29                                      NaN      NaN
# ...                                     ...      ...
# 1265                                    NaN      NaN
# 1266                                m.i.t.,      NaN
# 1267                                    NaN       15
# 1268                                    NaN      NaN
# 1269   mit laboratory for computer science,      NaN
# 1270                                    NaN   august
# 1271                                    NaN   august
# 1272                                    NaN      NaN
# 1273                                    NaN    july,
# 1274                                    NaN      NaN
# 1275                                    NaN      NaN
# 1276                                    NaN      NaN
# 1277                                    NaN      NaN
# 1278                                    NaN      NaN
# 1279                                    NaN      NaN
# 1280                                    NaN      NaN
# 1281                                    NaN      NaN
# 1282                                    NaN      NaN
# 1283                                    NaN      NaN
# 1284                                    NaN      NaN
# 1285                                    NaN      NaN
# 1286                                    NaN      NaN
# 1287                                    NaN      NaN
# 1288                                    NaN        9
# 1289                                    NaN      NaN
# 1290                                    NaN      NaN
# 1291                                    NaN      NaN
# 1292                                    NaN      NaN
# 1293                                    NaN      NaN
# 1294                                    NaN      NaN
#
#                                                    note            pages  \
# 0                                                   NaN     pages 42-49.
# 1                                                   NaN     pages 42-49.
# 2                                                   NaN              NaN
# 3                                                   NaN     (pp. 42-49),
# 4                                                   NaN              NaN
# 5                                                   NaN           42-49.
# 6                                                   NaN     pages 42-49.
# 7                                                   NaN     pages 42-49,
# 8                                                   NaN           42-49.
# 9                                                   NaN              NaN
# 10                                                  NaN        42-49. 14
# 11                                                  NaN     pages 42-49.
# 12                                                  NaN              NaN
# 13                                                  NaN       pp. 42-49,
# 14                                                  NaN              NaN
# 15                                                  NaN     pages 42-49,
# 16                                                  NaN     pages 42-49,
# 17                                                  NaN              NaN
# 18                                                  NaN           42-49.
# 19                                                  NaN       pp. 42-49.
# 20                                                  NaN       pp. 42-49.
# 21                           morgan kaufmann. 198 duda,     (pp. 42-49).
# 22                                         (to appear).              NaN
# 23                                         (to appear).              NaN
# 24                                                  NaN              NaN
# 25                                                  NaN   pages 483-490.
# 26                                                  NaN   (pp. 483-490).
# 27                                                  NaN              NaN
# 28                                                  NaN   pages 483-490,
# 29                                                  NaN         483-490.
# ...                                                 ...              ...
# 1265                                                NaN              NaN
# 1266                                                NaN              NaN
# 1267                                                NaN              NaN
# 1268                                                NaN              NaN
# 1269                                                NaN              NaN
# 1270                                                NaN              NaN
# 1271                                                NaN   pages 184-198,
# 1272                                                NaN              NaN
# 1273                                                NaN              NaN
# 1274                                                NaN              NaN
# 1275                                                NaN              NaN
# 1276                                                NaN     pp. 322-330.
# 1277                                           322-330.              pp.
# 1278                                                NaN              NaN
# 1279   (available at http://www.research.att.com/~yo...              NaN
# 1280                                                NaN              NaN
# 1281                                                NaN              NaN
# 1282                                                NaN              NaN
# 1283                                                NaN         322-330.
# 1284                                                NaN     pp. 322-330.
# 1285                                                NaN              NaN
# 1286                                      to appear. 11              NaN
# 1287                                                NaN              NaN
# 1288                                                NaN              NaN
# 1289                                                NaN              NaN
# 1290                                                NaN              NaN
# 1291                                                NaN              NaN
# 1292                                                NaN                1
# 1293                                                NaN    pages 322330,
# 1294                                                NaN         322-330.
#
#                                publisher ref_no  \
# 0                       morgan kaufmann,   0095
# 1                       morgan kaufmann,   0096
# 2                       morgan kaufmann.   0097
# 3                       morgan kaufmann.   0098
# 4                       morgan kaufmann,   0099
# 5                                    NaN   0100
# 6                       morgan kaufmann.   0101
# 7                       morgan kaufmann.   0102
# 8                       morgan kaufmann.   0103
# 9                       morgan kaufmann.   0104
# 10                                   NaN   0105
# 11                      morgan kaufmann,   0106
# 12                      morgan kaufmann,   0107
# 13                      morgan kaufmann.   0108
# 14                      morgan kaufmann.   0109
# 15                                   NaN   0110
# 16                      morgan kaufmann.   0111
# 17                      morgan kaufmann.   0112
# 18                      morgan kaufmann,   0113
# 19                                   NaN   0114
# 20                     morgan kauffmann,   0115
# 21                       addison-wesley.   0116
# 22                                   NaN   0181
# 23                                   NaN   0182
# 24                      morgan kaufmann.   0183
# 25                      morgan kaufmann,   0184
# 26                      morgan kaufmann,   0185
# 27                      morgan kaufmann,   0186
# 28                      morgan kaufmann.   0187
# 29                      morgan kaufmann.   0188
# ...                                  ...    ...
# 1265                          mit press,   1243
# 1266                                 NaN   1244
# 1267                      the mit press,   1245
# 1268                      the mit press,   1246
# 1269                                 NaN   1247
# 1270                                 NaN   1249
# 1271                                 NaN   1250
# 1272                          mit press,   1251
# 1273                                 NaN   1253
# 1274                    morgan kaufmann,   1263
# 1275                                 NaN   1264
# 1276                    morgan kaufmann,   1265
# 1277                    morgan kaufmann,   1266
# 1278                                 NaN   1267
# 1279                                 NaN   1268
# 1280     morgan kaufmann (1997) 322-330.   1269
# 1281     morgan kaufmann (1997) 322-330.   1270
# 1282                                 NaN   1271
# 1283                    morgan kaufmann.   1272
# 1284                    morgan kaufmann.   1273
# 1285                                 NaN   1274
# 1286   morgan kaufmann publishers, inc.,   1275
# 1287                                 NaN   1276
# 1288                                 NaN   1277
# 1289                                 NaN   1278
# 1290                                 NaN   1279
# 1291                                 NaN   1280
# 1292                                 NaN   1281
# 1293                                 NaN   1282
# 1294                    morgan kaufmann.   1283
#
#                                                   title  \
# 0      improving performance in neural networks usin...
# 1      improving performance in neural networks usin...
# 2      improving performance in neural networks usin...
# 3      improving performance in neural networks usin...
# 4      improving performance in neural networks usin...
# 5      improving the performance in neural networks ...
# 6      improving performance in neural networks usin...
# 7      improving performance in neural networks usin...
# 8     improving performance in neural networks using...
# 9     'improving performance in neural networks usin...
# 10     improving performance in neural networks usin...
# 11     improving performance in neural networks usin...
# 12     improving performance in neural networks usin...
# 13     'improving performance in neural networks usi...
# 14    'improving performance in neural networks usin...
# 15     improving performance in neural networks usin...
# 16     improving performance in neural networks usin...
# 17     improving performance in neural networks usin...
# 18     improving performance in neural networks usin...
# 19     improving the performance in neural networks ...
# 20     improving performance in neural networks usin...
# 21           pattern classification and scene analysis.
# 22     adaptive game playing using multiplicative we...
# 23     adaptive game playing using multiplicative we...
# 24     information, prediction, and query by committee.
# 25     information, prediction, and query by committee.
# 26     information, prediction, and query by committee.
# 27     information, prediction, and query by committee,
# 28       information, prediction and query by comittee.
# 29     information, prediction, and query by committee.
# ...                                                 ...
# 1265   the design and analysis of efficient learning...
# 1266   the design and analysis of efficient learning...
# 1267   the design and analysis of efficient learning...
# 1268   the design and analysis of efficient learning...
# 1269   the design and analysis of efficient learning...
# 1270   learning probabilistic read-once formulas on ...
# 1271   learning probabilistic read-once formulas on ...
# 1272   the design and analysis of ef ficient learnin...
# 1273   learning sparse multivariate polynomial over ...
# 1274   boosting the margin: a new explanation for th...
# 1275   boosting the margin: a new explanation for th...
# 1276   boosting the margin: a new explanation for th...
# 1277   boosting the margin: a new explanation for th...
# 1278   boosting the margin: a new explanation for th...
# 1279   lee (1997). boosting the margin : a new expla...
# 1280   boosting the margin: a new explanation for th...
# 1281  : boosting the margin: a new explanation for t...
# 1282                               boosting the margin:
# 1283   boosting the margin: a new explanation for th...
# 1284   bartlett & w.s. lee (1997), boosting the marg...
# 1285   boosting the margin: a new explanation for th...
# 1286   boosting the margin; a new explanation for th...
# 1287   boosting the margin: a new explanation for th...
# 1288   boosting the margin: a new explanation for th...
# 1289   boosting the margin: a new explanation for th...
# 1290   boosting the margin: a new explanation for th...
# 1291   boosting the margin: a new explanation for th...
# 1292   and w.s. leee. boosting the margin: a new exp...
# 1293   boosting the margin: a new explanation for th...
# 1294   w.s. boosting the margin: a new explanation f...
#
#                                                   venue      volume      year
# 0      advances in neural information processing sys...   volume 5,      1993
# 1      advances in neural information processing sys...   volume 5,      1993
# 2      in advances in neural information processing ...         NaN   (1992).
# 3      advances in neural information processing sys...         NaN   (1992).
# 4      advances in neural information processing sys...         NaN   (1993).
# 5      advances in neural information processing sys...          5,   (1993).
# 6      advances in neural information processing sys...   volume 5,   (1993).
# 7      advances in neural information processing sys...         NaN      1993
# 8      in advances in neural informations processing...         NaN      1993
# 9      in advances in neural information processing ...         NaN      1993
# 10     advances in neural information processing sys...         NaN     1993,
# 11     advances in neural information processing sys...         NaN      1993
# 12     in advances in neural information processing ...         NaN      1992
# 13     in advances in neural information processing ...         NaN     1993,
# 14     in advances in neural information processing ...         NaN      1993
# 15     in advances in neural information processing ...         NaN      1993
# 16     in advances in neural informations processing...         NaN      1993
# 17     in proceedings of the fifth conf. on neural i...         NaN      1993
# 18     advances in neural information processing sys...     vol. 5,     1993,
# 19     advances in neural information processing sys...          5,   (1993),
# 20             `neural information processing systems',         NaN   (1993),
# 21     advances in neural information processing sys...   volume 5,   (1973).
# 22    games and economic behavior, in proc. of ieee ...         NaN         0
# 23    games and economic behavior, in proc. of ieee ...         NaN         0
# 24     in advances in neural informations processing...         NaN      1993
# 25     advances in neural information processing sys...   volume 5,      1993
# 26     advances in neural information processing sys...   volume 5,   (1993).
# 27     in `advances in neural information processing...     vol. 5,   (1993),
# 28     advances in neural information processing sys...   volume 5,   (1993).
# 29     in advances in neural informations processing...         NaN      1992
# ...                                                 ...         ...       ...
# 1265                                        phd thesis,         NaN      1992
# 1266                                        phd thesis,         NaN      1991
# 1267                                        phd thesis,         NaN      1992
# 1268                                        phd thesis,         NaN      1992
# 1269                   technical report mit/lcs/tr-493,         NaN      1991
# 1270   in computation learning theory: proceedings o...         NaN      1991
# 1271   in proceedings of the fourth annual workshop ...         NaN      1991
# 1272   in proceedings of the fourth annual workshop ...         NaN      1992
# 1273   in proceedings of the sixth annual acm worksh...         NaN      1993
# 1274   in proceedings of the fourteenth internationa...         NaN      1997
# 1275   in machine learning: proceedings of the fourt...         NaN   (1997).
# 1276   `machine learning: proceedings of the fourtee...         NaN   (1997),
# 1277   `machine learning: proceedings of the fourtee...         NaN   (1997),
# 1278   in proceedings of the 14th international conf...         NaN   (1997).
# 1279   in proceedings of the 14th international conf...         NaN      1997
# 1280   proceedings of the 11th international confere...         NaN      1997
# 1281   proceedings of the fourteenth international c...         NaN      1997
# 1282   proceedings of the fourteenth international c...         NaN      1997
# 1283   in proceedings of the 14th international conf...         NaN      1997
# 1284   in proceedings of the fourteenth internationa...         NaN      1997
# 1285                          snowbird 1997 conference.         NaN   (1997),
# 1286   in proceedings of the fourteenth internationa...         NaN      1997
# 1287   in proceedings of the fourteenth internationa...         NaN   (1997).
# 1288   in machine learning: proceedings of the fourt...         NaN      1997
# 1289   in machine learning: proceedings of the fourt...         NaN      1997
# 1290   in machine learning: proceedings of the fourt...         NaN      1997
# 1291   in machine learning: proceedings of the fourt...         NaN      1997
# 1292                                               1997         NaN      1997
# 1293                                        in icml-97,         NaN      1997
# 1294   in proceedings of the 14th international conf...         NaN      1997
#
# [1295 rows x 15 columns]

# %%
dfrelevant = pd.DataFrame({'class_no':df['class_no'], 'authors':df['author'], 
                           'authors_as_list':authors_with_class['author_list'],
                           'title':df['title'],'year':years['year']})
dfrelevant['pubid'] = dfrelevant.index
dfrelevant
# Out:
#                                                 authors  \
# 0               h. drucker, r. schapire, and p. simard.
# 1               h. drucker, r. schapire, and p. simard.
# 2                  drucker h., schapire r., & simard p.
# 3                  drucker h., schapire r., & simard p.
# 4                  drucker h., schapire r., & simard p.
# 5                  drucker h., schapire r., & simard p.
# 6                drucker h., schapire r., and simard p.
# 7                drucker h., schapire r., and simard r.
# 8     drucker harris, schapire, robert, and simard p...
# 9                    drucker h., schapire r., simard p.
# 10                        drucker, schapire, and simard
# 11    harris drucker, robert schapire, and patrice s...
# 12    harris drucker, robert schapire, and patrice s...
# 13               h. drucker, r. schapire, and p. simard
# 14                   drucker h., schapire r., simard p.
# 15    harris drucker, robert schapire, and patrice s...
# 16    harris drucker, robert schapire, and patrice s...
# 17    harris drucker, robert e. schapire, and ptrice...
# 18                    h. druker, r. schapire, p. simard
# 19                        drucker h., r. schapire, & p.
# 20                 drucker h., schapire r., & simard p.
# 21                                        r., & hart p.
# 22                 yoav freund, and robert e. schapire.
# 23                 yoav freund, and robert e. schapire.
# 24    y. freund, h. s. seung, e. shamir, and n. tishby.
# 25    yoav freund, h. sebastian seung, eli shamir, a...
# 26       freund y., seung h. s., shamir e., & tishby n.
# 27          freund y., seung h., shamir e., & tishby n.
# 28        freund y., seung h., shamir e., and tishby n.
# 29      freund y., seung h.s., shamir e., and tishby n.
# ...                                                 ...
# 1265                                    r. e. schapire.
# 1266                                robert e. schapire.
# 1267                                      schapire r.e.
# 1268                                      schapire r.e.
# 1269                                robert e. schapire.
# 1270                                robert e. schapire.
# 1271                                robert e. schapire.
# 1272                                    r. e. schapire.
# 1273                      r. e. schapire, l. m. sellie.
# 1274    schapire r.e., freund y., bartlett p., lee w.s.
# 1275  r. e. schapire, y. freund, p. bartlett, and w....
# 1276  schapire r. e., freund y., bartlett p., & lee ...
# 1277  schapire r. e., freund y., bartlett p., & lee ...
# 1278    schapire r., freund y., bartlett p., and lee w.
# 1279        schapire r., y. freund, p. bartlett, and w.
# 1280  schapire r.e., freund y., bartlett p., and lee...
# 1281  schapire r.e., freund y., bartlett p., and lee...
# 1282  schapire r.e., freund y., bartlett p., and lee...
# 1283  schapire r.e., freund y., bartlett p., and lee...
# 1284                       schapire r.e., y. freund, p.
# 1285       shapire r., freund y., bartlett p., & lee w.
# 1286  r. schapire, y. freund, p. bartlett, and w. s....
# 1287  schapire r. e., freund y., bartlett p., & lee ...
# 1288  robert e. schapire, yoav freund, peter bartlet...
# 1289  robert e. schapire, yoav freund, peter bartlet...
# 1290  robert e. schapire, yoav freund, peter bartlet...
# 1291  robert e. schapire, yoav freund, peter bartlet...
# 1292              r.e. schapire, y. freund, p. bartlett
# 1293   r. schapire, y. freund, p. bartlett, and w. lee.
# 1294    schapire, r.e., freund y., bartlett p., and lee
#
#                                         authors_as_list        class_no  \
# 0                [h. drucker,  r. schapire, p. simard.]     drucker1992
# 1                [h. drucker,  r. schapire, p. simard.]     drucker1992
# 2               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 3               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 4               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 5               [drucker h.,  schapire r.,   simard p.]     drucker1992
# 6                 [drucker h.,  schapire r., simard p.]     drucker1992
# 7                 [drucker h.,  schapire r., simard r.]     drucker1992
# 8     [drucker harris,  schapire,  robert, simard pa...     drucker1992
# 9                [drucker h.,  schapire r.,  simard p.]     drucker1992
# 10                         [drucker,  schapire, simard]     drucker1992
# 11    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 12    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 13                [h. drucker,  r. schapire, p. simard]     drucker1992
# 14               [drucker h.,  schapire r.,  simard p.]     drucker1992
# 15    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 16    [harris drucker,  robert schapire, patrice sim...     drucker1992
# 17    [harris drucker,  robert e. schapire, ptrice s...     drucker1992
# 18                [h. druker,  r. schapire,  p. simard]     drucker1992
# 19                     [drucker h.,  r. schapire,   p.]     drucker1992
# 20              [drucker h.,  schapire r.,   simard p.]     drucker1992
# 21                                      [r.,   hart p.]   drucker1992C1
# 22                   [yoav freund, robert e. schapire.]     freund0000a
# 23                   [yoav freund, robert e. schapire.]     freund0000a
# 24    [y. freund,  h. s. seung,  e. shamir, n. tishby.]     freund1992a
# 25    [yoav freund,  h. sebastian seung,  eli shamir...     freund1992a
# 26    [freund y.,  seung h. s.,  shamir e.,   tishby...     freund1992a
# 27      [freund y.,  seung h.,  shamir e.,   tishby n.]     freund1992a
# 28        [freund y.,  seung h.,  shamir e., tishby n.]     freund1992a
# 29      [freund y.,  seung h.s.,  shamir e., tishby n.]     freund1992a
# ...                                                 ...             ...
# 1265                                  [r. e. schapire.]    schapire1991
# 1266                              [robert e. schapire.]    schapire1991
# 1267                                    [schapire r.e.]    schapire1991
# 1268                                    [schapire r.e.]    schapire1991
# 1269                              [robert e. schapire.]  schapire1991C1
# 1270                              [robert e. schapire.]   schapire1991l
# 1271                              [robert e. schapire.]   schapire1991l
# 1272                                  [r. e. schapire.]    schapire1992
# 1273                   [r. e. schapire,  l. m. sellie.]    schapire1993
# 1274  [schapire r.e.,  freund y.,  bartlett p.,  lee...    schapire1997
# 1275  [r. e. schapire,  y. freund,  p. bartlett, w. ...    schapire1997
# 1276  [schapire r. e.,  freund y.,  bartlett p.,   l...    schapire1997
# 1277  [schapire r. e.,  freund y.,  bartlett p.,   l...    schapire1997
# 1278    [schapire r.,  freund y.,  bartlett p., lee w.]    schapire1997
# 1279        [schapire r.,  y. freund,  p. bartlett, w.]    schapire1997
# 1280  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1281  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1282  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1283  [schapire r.e.,  freund y.,  bartlett p., lee ...    schapire1997
# 1284                   [schapire r.e.,  y. freund,  p.]    schapire1997
# 1285   [shapire r.,  freund y.,  bartlett p.,   lee w.]    schapire1997
# 1286  [r. schapire,  y. freund,  p. bartlett, w. s. ...    schapire1997
# 1287  [schapire r. e.,  freund y.,  bartlett p.,   l...    schapire1997
# 1288  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1289  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1290  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1291  [robert e. schapire,  yoav freund,  peter bart...    schapire1997
# 1292          [r.e. schapire,  y. freund,  p. bartlett]    schapire1997
# 1293   [r. schapire,  y. freund,  p. bartlett, w. lee.]    schapire1997
# 1294   [schapire,  r.e.,  freund y.,  bartlett p., lee]    schapire1997
#
#                                                   title  year  pubid
# 0      improving performance in neural networks usin...  1993      0
# 1      improving performance in neural networks usin...  1993      1
# 2      improving performance in neural networks usin...  1992      2
# 3      improving performance in neural networks usin...  1992      3
# 4      improving performance in neural networks usin...  1993      4
# 5      improving the performance in neural networks ...  1993      5
# 6      improving performance in neural networks usin...  1993      6
# 7      improving performance in neural networks usin...  1993      7
# 8     improving performance in neural networks using...  1993      8
# 9     'improving performance in neural networks usin...  1993      9
# 10     improving performance in neural networks usin...  1993     10
# 11     improving performance in neural networks usin...  1993     11
# 12     improving performance in neural networks usin...  1992     12
# 13     'improving performance in neural networks usi...  1993     13
# 14    'improving performance in neural networks usin...  1993     14
# 15     improving performance in neural networks usin...  1993     15
# 16     improving performance in neural networks usin...  1993     16
# 17     improving performance in neural networks usin...  1993     17
# 18     improving performance in neural networks usin...  1993     18
# 19     improving the performance in neural networks ...  1993     19
# 20     improving performance in neural networks usin...  1993     20
# 21           pattern classification and scene analysis.  1973     21
# 22     adaptive game playing using multiplicative we...     0     22
# 23     adaptive game playing using multiplicative we...     0     23
# 24     information, prediction, and query by committee.  1993     24
# 25     information, prediction, and query by committee.  1993     25
# 26     information, prediction, and query by committee.  1993     26
# 27     information, prediction, and query by committee,  1993     27
# 28       information, prediction and query by comittee.  1993     28
# 29     information, prediction, and query by committee.  1992     29
# ...                                                 ...   ...    ...
# 1265   the design and analysis of efficient learning...  1992   1265
# 1266   the design and analysis of efficient learning...  1991   1266
# 1267   the design and analysis of efficient learning...  1992   1267
# 1268   the design and analysis of efficient learning...  1992   1268
# 1269   the design and analysis of efficient learning...  1991   1269
# 1270   learning probabilistic read-once formulas on ...  1991   1270
# 1271   learning probabilistic read-once formulas on ...  1991   1271
# 1272   the design and analysis of ef ficient learnin...  1992   1272
# 1273   learning sparse multivariate polynomial over ...  1993   1273
# 1274   boosting the margin: a new explanation for th...  1997   1274
# 1275   boosting the margin: a new explanation for th...  1997   1275
# 1276   boosting the margin: a new explanation for th...  1997   1276
# 1277   boosting the margin: a new explanation for th...  1997   1277
# 1278   boosting the margin: a new explanation for th...  1997   1278
# 1279   lee (1997). boosting the margin : a new expla...  1997   1279
# 1280   boosting the margin: a new explanation for th...  1997   1280
# 1281  : boosting the margin: a new explanation for t...  1997   1281
# 1282                               boosting the margin:  1997   1282
# 1283   boosting the margin: a new explanation for th...  1997   1283
# 1284   bartlett & w.s. lee (1997), boosting the marg...  1997   1284
# 1285   boosting the margin: a new explanation for th...  1997   1285
# 1286   boosting the margin; a new explanation for th...  1997   1286
# 1287   boosting the margin: a new explanation for th...  1997   1287
# 1288   boosting the margin: a new explanation for th...  1997   1288
# 1289   boosting the margin: a new explanation for th...  1997   1289
# 1290   boosting the margin: a new explanation for th...  1997   1290
# 1291   boosting the margin: a new explanation for th...  1997   1291
# 1292   and w.s. leee. boosting the margin: a new exp...  1997   1292
# 1293   boosting the margin: a new explanation for th...  1997   1293
# 1294   w.s. boosting the margin: a new explanation f...  1997   1294
#
# [1295 rows x 6 columns]

# %%
#Number of blocks:
print(len(dfrelevant['year'].unique()))
dfrelevant['year'].unique()
# Clearly there will be errors - see 0, 11995
# Out:
# 17
# array([ 1993,  1992,  1973,     0,  1995,  1996,  1997,  1990,  1988,
#         1991,  1994,  1987,  1989,  1998,  2000, 11995,  1999])

# %%
'''
So, the list of predicates we want is:
Blocking:
Block Author        x
Block Publication   x

Obs:
haveSimTitle
hasAuthor           x
haveSimilarNames
haveSimilarAuthors
areCoAuthors        x

Targets and GroundTruth:
SamePub
SameAuthor
'''

'''
 DataFrame.to_csv(path_or_buf=None, sep=', ', na_rep='', float_format=None, columns=None, 
                  header=True, index=True, index_label=None, mode='w', encoding=None, 
                  compression=None, quoting=None, quotechar='"', line_terminator='\n', 
                  chunksize=None, tupleize_cols=False, date_format=None, doublequote=True, 
                  escapechar=None, decimal='.')[source]
'''

# Block publications
dfrelevant[['pubid','year']].to_csv(wdir+'/psl/BlocksPubs.txt',sep='\t',header=False,index=False)

# %%
# hasAuthor
# areCoAuthors

# Note that in the absence of an author identifier, and in the presence of multiple authors per publication
#    we must use a unique author id for every mention in the publication, because PSL treats the same literal 
#    value to mean the same entity
# We can make use of this to also segregate the names into first, middle, last names and initials
# We also need to block authors

# First come up with identifiers for the Authors. An authorid -> authorname file: AuthorNames.txt
# Also, it will be useful to block authors. An authorid -> blockid file: BlocksAuthors.txt
authid = 0 
from itertools import combinations

with open(wdir+'/psl/AuthorNames.txt','w') as file_authors, \
     open(wdir+'/psl/HasAuthor.txt','w') as file_hasAuthor, \
     open(wdir+'/psl/AreCoAuthors.txt','w') as file_areCoAuthors, \
     open(wdir+'/psl/AuthorTrace.txt','w') as file_authorTrace, \
     open(wdir+'/psl/BlocksAuthors.txt','w') as file_blocksAuthors:
    for index, row in dfrelevant.iterrows():
        authids_for_this_pub = list()
        for author in row['authors_as_list']:
            if author.strip() == '':
                continue
            authids_for_this_pub.append(authid)
            file_authors.write('{}\t{}\n'.format(authid, author.strip()))
            file_hasAuthor.write('{}\t{}\n'.format(index, authid))
            file_blocksAuthors.write('{}\t{}\n'.format(authid, row['year']))
            file_authorTrace.write('{}\t{}\t{}\n'.format(authid, author.strip(), index))
            authid += 1
            
        for auth1, auth2 in combinations(authids_for_this_pub,2):
            file_areCoAuthors.write('{}\t{}\n'.format(auth1, auth2))
            file_areCoAuthors.write('{}\t{}\n'.format(auth2, auth1))

# %%
# Similarities.
# Note that this is where we will have cross products
# areCoAuthors should technically have a cross product of authors,
#     but let's see if we can imply that as a closed predicate, not-mentioned pairs are false.

# haveSimTitle
# haveSimilarAuthors
# haveSimilarNames (for authors)

# %%
# Let's begin with the smallest of the cross products: haveSimilarNames
# First read the AuthorNames files as a dataframe
dfauthors_names = pd.read_csv(wdir+'/psl/AuthorNames.txt', sep='\t', names=['author_id','name'], header=None)

# Then read their block information
dfauthors_blocks = pd.read_csv(wdir+'/psl/BlocksAuthors.txt', sep='\t', names=['author_id','block'], header=None)

# Combine the dataframes by author_id
# Note that this can be done at this stage 
#    because we assume every mention is a unique author
#    until further evidence
dfauthors = dfauthors_names.merge(dfauthors_blocks, on='author_id')

# Then get the cross product.
dfauthors_cross = dfauthors.merge(dfauthors, on='block')

# %%
# Now you can add a column for similarity between name_x and name_y
# TODO: Just realized - Blocking on year makes sense for publications,
#       but not really for authors. If we compare authors only for 
#       publications in the same year, we may not even hit the same 
#       author twice :/
#       Also, this flouts the meaning of a block - a cluster of mentions
#             that are likely the same entity
#       Suggestion: use a different blocking scheme, and different blocks

# %%
dfauthors = dfauthors_names.merge(dfauthors_blocks, on='author_id')
dfauthors
# Out:
#       author_id                name  block
# 0             0          h. drucker   1993
# 1             1         r. schapire   1993
# 2             2          p. simard.   1993
# 3             3          h. drucker   1993
# 4             4         r. schapire   1993
# 5             5          p. simard.   1993
# 6             6          drucker h.   1992
# 7             7         schapire r.   1992
# 8             8           simard p.   1992
# 9             9          drucker h.   1992
# 10           10         schapire r.   1992
# 11           11           simard p.   1992
# 12           12          drucker h.   1993
# 13           13         schapire r.   1993
# 14           14           simard p.   1993
# 15           15          drucker h.   1993
# 16           16         schapire r.   1993
# 17           17           simard p.   1993
# 18           18          drucker h.   1993
# 19           19         schapire r.   1993
# 20           20           simard p.   1993
# 21           21          drucker h.   1993
# 22           22         schapire r.   1993
# 23           23           simard r.   1993
# 24           24      drucker harris   1993
# 25           25            schapire   1993
# 26           26              robert   1993
# 27           27      simard patrice   1993
# 28           28          drucker h.   1993
# 29           29         schapire r.   1993
# ...         ...                 ...    ...
# 3493       3493         bartlett p.   1997
# 3494       3494           lee w. s.   1997
# 3495       3495  robert e. schapire   1997
# 3496       3496         yoav freund   1997
# 3497       3497      peter bartlett   1997
# 3498       3498        wee sun lee.   1997
# 3499       3499  robert e. schapire   1997
# 3500       3500         yoav freund   1997
# 3501       3501      peter bartlett   1997
# 3502       3502        wee sun lee.   1997
# 3503       3503  robert e. schapire   1997
# 3504       3504         yoav freund   1997
# 3505       3505      peter bartlett   1997
# 3506       3506        wee sun lee.   1997
# 3507       3507  robert e. schapire   1997
# 3508       3508         yoav freund   1997
# 3509       3509      peter bartlett   1997
# 3510       3510        wee sun lee.   1997
# 3511       3511       r.e. schapire   1997
# 3512       3512           y. freund   1997
# 3513       3513         p. bartlett   1997
# 3514       3514         r. schapire   1997
# 3515       3515           y. freund   1997
# 3516       3516         p. bartlett   1997
# 3517       3517             w. lee.   1997
# 3518       3518            schapire   1997
# 3519       3519                r.e.   1997
# 3520       3520           freund y.   1997
# 3521       3521         bartlett p.   1997
# 3522       3522                 lee   1997
#
# [3523 rows x 3 columns]

# %%
dfauthors
# Out:
#       author_id                name  block              bc1
# 0             0          h. drucker   1993         {h, dru}
# 1             1         r. schapire   1993         {r, sch}
# 2             2          p. simard.   1993         {p, sim}
# 3             3          h. drucker   1993         {h, dru}
# 4             4         r. schapire   1993         {r, sch}
# 5             5          p. simard.   1993         {p, sim}
# 6             6          drucker h.   1992         {h, dru}
# 7             7         schapire r.   1992         {r, sch}
# 8             8           simard p.   1992         {p, sim}
# 9             9          drucker h.   1992         {h, dru}
# 10           10         schapire r.   1992         {r, sch}
# 11           11           simard p.   1992         {p, sim}
# 12           12          drucker h.   1993         {h, dru}
# 13           13         schapire r.   1993         {r, sch}
# 14           14           simard p.   1993         {p, sim}
# 15           15          drucker h.   1993         {h, dru}
# 16           16         schapire r.   1993         {r, sch}
# 17           17           simard p.   1993         {p, sim}
# 18           18          drucker h.   1993         {h, dru}
# 19           19         schapire r.   1993         {r, sch}
# 20           20           simard p.   1993         {p, sim}
# 21           21          drucker h.   1993         {h, dru}
# 22           22         schapire r.   1993         {r, sch}
# 23           23           simard r.   1993         {r, sim}
# 24           24      drucker harris   1993       {har, dru}
# 25           25            schapire   1993            {sch}
# 26           26              robert   1993            {rob}
# 27           27      simard patrice   1993       {sim, pat}
# 28           28          drucker h.   1993         {h, dru}
# 29           29         schapire r.   1993         {r, sch}
# ...         ...                 ...    ...              ...
# 3493       3493         bartlett p.   1997         {bar, p}
# 3494       3494           lee w. s.   1997      {w, lee, s}
# 3495       3495  robert e. schapire   1997    {e, rob, sch}
# 3496       3496         yoav freund   1997       {fre, yoa}
# 3497       3497      peter bartlett   1997       {pet, bar}
# 3498       3498        wee sun lee.   1997  {sun, lee, wee}
# 3499       3499  robert e. schapire   1997    {e, rob, sch}
# 3500       3500         yoav freund   1997       {fre, yoa}
# 3501       3501      peter bartlett   1997       {pet, bar}
# 3502       3502        wee sun lee.   1997  {sun, lee, wee}
# 3503       3503  robert e. schapire   1997    {e, rob, sch}
# 3504       3504         yoav freund   1997       {fre, yoa}
# 3505       3505      peter bartlett   1997       {pet, bar}
# 3506       3506        wee sun lee.   1997  {sun, lee, wee}
# 3507       3507  robert e. schapire   1997    {e, rob, sch}
# 3508       3508         yoav freund   1997       {fre, yoa}
# 3509       3509      peter bartlett   1997       {pet, bar}
# 3510       3510        wee sun lee.   1997  {sun, lee, wee}
# 3511       3511       r.e. schapire   1997      {e, r, sch}
# 3512       3512           y. freund   1997         {fre, y}
# 3513       3513         p. bartlett   1997         {bar, p}
# 3514       3514         r. schapire   1997         {r, sch}
# 3515       3515           y. freund   1997         {fre, y}
# 3516       3516         p. bartlett   1997         {bar, p}
# 3517       3517             w. lee.   1997         {w, lee}
# 3518       3518            schapire   1997            {sch}
# 3519       3519                r.e.   1997           {e, r}
# 3520       3520           freund y.   1997         {fre, y}
# 3521       3521         bartlett p.   1997         {bar, p}
# 3522       3522                 lee   1997            {lee}
#
# [3523 rows x 4 columns]

# %%
# Add blocking condition(s) as (a) column(s)
# Remember, it needs to be inexpensive to compare
dfauthors['blockcondition1_3letters'] = dfauthors['name'].apply(lambda x : set([part_of_name.replace('.','')[:3] for part_of_name in x.split(' ')]))
dfauthors['blockcondition2_sortedInitials'] = dfauthors['name'].apply(lambda x : ''.join(sorted([part_of_name[0] for part_of_name in x.replace('.','').split(' ') if part_of_name !=''])))
# Let's say 2 author mentions are in the same block if 
# 1. intersection of their blockcondition1 has at least one element
# 2. their blockcondition2 has a substring-superstring relationship
# 3. there is at least one 3 letter match in the intersection of blockcondition1

# %%
dfauthors
# Out:
#       author_id                name  block blockcondition1_3letters  \
# 0             0          h. drucker   1993                 {h, dru}
# 1             1         r. schapire   1993                 {r, sch}
# 2             2          p. simard.   1993                 {p, sim}
# 3             3          h. drucker   1993                 {h, dru}
# 4             4         r. schapire   1993                 {r, sch}
# 5             5          p. simard.   1993                 {p, sim}
# 6             6          drucker h.   1992                 {h, dru}
# 7             7         schapire r.   1992                 {r, sch}
# 8             8           simard p.   1992                 {p, sim}
# 9             9          drucker h.   1992                 {h, dru}
# 10           10         schapire r.   1992                 {r, sch}
# 11           11           simard p.   1992                 {p, sim}
# 12           12          drucker h.   1993                 {h, dru}
# 13           13         schapire r.   1993                 {r, sch}
# 14           14           simard p.   1993                 {p, sim}
# 15           15          drucker h.   1993                 {h, dru}
# 16           16         schapire r.   1993                 {r, sch}
# 17           17           simard p.   1993                 {p, sim}
# 18           18          drucker h.   1993                 {h, dru}
# 19           19         schapire r.   1993                 {r, sch}
# 20           20           simard p.   1993                 {p, sim}
# 21           21          drucker h.   1993                 {h, dru}
# 22           22         schapire r.   1993                 {r, sch}
# 23           23           simard r.   1993                 {r, sim}
# 24           24      drucker harris   1993               {har, dru}
# 25           25            schapire   1993                    {sch}
# 26           26              robert   1993                    {rob}
# 27           27      simard patrice   1993               {sim, pat}
# 28           28          drucker h.   1993                 {h, dru}
# 29           29         schapire r.   1993                 {r, sch}
# ...         ...                 ...    ...                      ...
# 3493       3493         bartlett p.   1997                 {bar, p}
# 3494       3494           lee w. s.   1997              {w, lee, s}
# 3495       3495  robert e. schapire   1997            {e, rob, sch}
# 3496       3496         yoav freund   1997               {fre, yoa}
# 3497       3497      peter bartlett   1997               {pet, bar}
# 3498       3498        wee sun lee.   1997          {sun, lee, wee}
# 3499       3499  robert e. schapire   1997            {e, rob, sch}
# 3500       3500         yoav freund   1997               {fre, yoa}
# 3501       3501      peter bartlett   1997               {pet, bar}
# 3502       3502        wee sun lee.   1997          {sun, lee, wee}
# 3503       3503  robert e. schapire   1997            {e, rob, sch}
# 3504       3504         yoav freund   1997               {fre, yoa}
# 3505       3505      peter bartlett   1997               {pet, bar}
# 3506       3506        wee sun lee.   1997          {sun, lee, wee}
# 3507       3507  robert e. schapire   1997            {e, rob, sch}
# 3508       3508         yoav freund   1997               {fre, yoa}
# 3509       3509      peter bartlett   1997               {pet, bar}
# 3510       3510        wee sun lee.   1997          {sun, lee, wee}
# 3511       3511       r.e. schapire   1997                {re, sch}
# 3512       3512           y. freund   1997                 {fre, y}
# 3513       3513         p. bartlett   1997                 {bar, p}
# 3514       3514         r. schapire   1997                 {r, sch}
# 3515       3515           y. freund   1997                 {fre, y}
# 3516       3516         p. bartlett   1997                 {bar, p}
# 3517       3517             w. lee.   1997                 {w, lee}
# 3518       3518            schapire   1997                    {sch}
# 3519       3519                r.e.   1997                     {re}
# 3520       3520           freund y.   1997                 {fre, y}
# 3521       3521         bartlett p.   1997                 {bar, p}
# 3522       3522                 lee   1997                    {lee}
#
#      blockcondition2_sortedInitials
# 0                                dh
# 1                                rs
# 2                                ps
# 3                                dh
# 4                                rs
# 5                                ps
# 6                                dh
# 7                                rs
# 8                                ps
# 9                                dh
# 10                               rs
# 11                               ps
# 12                               dh
# 13                               rs
# 14                               ps
# 15                               dh
# 16                               rs
# 17                               ps
# 18                               dh
# 19                               rs
# 20                               ps
# 21                               dh
# 22                               rs
# 23                               rs
# 24                               dh
# 25                                s
# 26                                r
# 27                               ps
# 28                               dh
# 29                               rs
# ...                             ...
# 3493                             bp
# 3494                            lsw
# 3495                            ers
# 3496                             fy
# 3497                             bp
# 3498                            lsw
# 3499                            ers
# 3500                             fy
# 3501                             bp
# 3502                            lsw
# 3503                            ers
# 3504                             fy
# 3505                             bp
# 3506                            lsw
# 3507                            ers
# 3508                             fy
# 3509                             bp
# 3510                            lsw
# 3511                             rs
# 3512                             fy
# 3513                             bp
# 3514                             rs
# 3515                             fy
# 3516                             bp
# 3517                             lw
# 3518                              s
# 3519                              r
# 3520                             fy
# 3521                             bp
# 3522                              l
#
# [3523 rows x 5 columns]

# %%
# TODO: Compare the blocking schemes
# TODO: Write a universal blocking stats calculating function
#       Signature will likely be - blockstats(blocks, groundtruth)
#       Which brings me to my moment of truth - where is the ground truth for same authors :/

# Let's try deriving it from the databases shared by the UW group
# As mentioned, we have a seed set of 21 authors:
uf_authors.printDisjointSets()
# That's a pretty good set of sets.
# We must now look at 
# 1) authors who are not first author in any publication 
#      (according to the statistic shared in the paper, these should be about 29 in number)
# 2) author mentions that belong to one of these sets
# Let's look at the number of distinct names that are not one of the names in these 21 sets
# Out:
# Disjoint sets:
# {'a_blum_', 'blum_a_', 'avrim_blum_'}
# {'schapire_r_e_', 'shapire_r_', 'r_schapire_', 'schapire_', 'robert_schapire_', 'r_', 'robert_e_schapire_', 'schapire_r_', 'schapire_robert_e_', 'shapire_r_e_', 'r_e_schapire_'}
# {'n_cesa_bianchi_', 'cesa_bianchi_n_', 'nicolo_cesa_bianchi_'}
# {'goldman_s_', 's_a_goldman_', 'goldman_s_a_', 'sally_a_goldman_', 's_goldman_'}
# {'kautz_henry_'}
# {'d_p_helmbold_', 'david_p_helmhold_', 'david_p_helmbold_', 'helmbold_d_p_', 'd_helmbold_'}
# {'p_auer_'}
# {'r_l_rivest_', 'rivest_ronald_l_', 'rivest_r_l_', 'rivest_r_', 'r_rivest_', 'ronald_l_rivest_'}
# {'littlestone_n_'}
# {'freud_y_', 'yoav_freund_', 'freund_y_', 'freund_v_', 'y_freund_', 'freund_yoav_'}
# {'d_haussler_', 'haussler_david_', 'haussler_d_', 'david_haussler_'}
# {'d_d_lewis_', 'david_d_lewis_', 'lewis_d_d_', 'lewis_d_', 'david_lewis_', 'd_lewis_'}
# {'j_p_kearns_'}
# {'ehrenfeucht_a_', 'ehrenfeucht_andrzej_', 'andrzej_ehrenfeucht_', 'a_ehrenfeucht_'}
# {'eric_bauer_'}
# {'kearns_m_', 'micahel_kearns_', 'kearns_', 'm_j_kearns_', 'michael_j_kearns_', 'michael_kearns_', 'm_kearns_', 'kearns_m_j_', 'kearns_michael_'}
# {'drucker_', 'harris_drucker_', 'drucker_harris_', 'h_druker_', 'drucker_h_', 'h_drucker_'}
# {'t_g_dietterich_', 'dietterich_t_', 't_dietterich_', 'tom_dietterich_', 'dietterich_t_g_'}
# {'m_feder_'}
# {'henry_kautz_', 'kautz_henry_a_', 'h_a_kautz_', 'kautz_h_', 'henry_a_kautz_', 'h_kautz_', 'kautz_h_a_'}
# {'william_w_cohen_', 'w_w_cohen_'}

# %%
# First normalize both sets to the form where the name is just the parts separated by spaces:
authors_known_ground_truth = set()
for author_set in uf_authors.getDisjointSets():
    for author in author_set:
        authors_known_ground_truth.add(author.replace('_',' ').strip())
print(len(authors_known_ground_truth))
print(authors_known_ground_truth)

authors_all = set()
for index, row in dfauthors.iterrows():
    authors_all.add(row['name'].replace('.',''))
print(len(authors_all))
print(authors_all)

# There are 85 out of 88 overlaps. Why not 88?
print(authors_known_ground_truth - authors_all)
# Interesting... it has to do with cesa bianchi in the ground truth dataset vs cesa-bianchi in the raw names
# Out:
# 88
# {'nicolo cesa bianchi', 'kautz henry', 'david d lewis', 'andrzej ehrenfeucht', 'shapire r e', 'blum a', 'tom dietterich', 'a blum', 'freund yoav', 'd d lewis', 'freund y', 'lewis d', 'freund v', 'david p helmbold', 'kautz h a', 'haussler david', 'h kautz', 'sally a goldman', 'dietterich t g', 'h a kautz', 'kearns', 'freud y', 'y freund', 'drucker h', 't dietterich', 'r rivest', 'kautz h', 'henry kautz', 'm kearns', 'david haussler', 'shapire r', 'j p kearns', 'r l rivest', 'kearns michael', 'r schapire', 'yoav freund', 'rivest r', 'goldman s', 'ehrenfeucht a', 'h drucker', 'robert schapire', 'eric bauer', 'd helmbold', 'd haussler', 't g dietterich', 'david p helmhold', 'michael j kearns', 'ehrenfeucht andrzej', 'drucker', 'drucker harris', 'd lewis', 'haussler d', 'r', 'm feder', 'r e schapire', 'a ehrenfeucht', 'michael kearns', 'schapire robert e', 'p auer', 'robert e schapire', 'william w cohen', 's goldman', 's a goldman', 'h druker', 'helmbold d p', 'dietterich t', 'rivest ronald l', 'cesa bianchi n', 'schapire r', 'kautz henry a', 'w w cohen', 'harris drucker', 'david lewis', 'kearns m', 'n cesa bianchi', 'goldman s a', 'ronald l rivest', 'm j kearns', 'kearns m j', 'micahel kearns', 'rivest r l', 'schapire r e', 'schapire', 'avrim blum', 'd p helmbold', 'lewis d d', 'henry a kautz', 'littlestone n'}
# 264
# {'ron kohavi', 'm war muth', 'ronitt rubinfeld', 'david d lewis', 'warmuth m k', 'yoram singer boostexter:', 'kautz henry', 'andrzej ehrenfeucht', 'merrick furst', 'umesh v vazirani', 'valiant', 'y singer', 'hs seung', 'shapire r e', 'blum a', 'lee ws', 'w lee', 'peter bartlett', 'tom dietterich', 'selman bart', 'warmuth m', 'wee sun lee', 'a blum', 'u v vazirani', 'lee w s', 'h seung', 'freund yoav', 'lm sellie', 'l valiant', 'j callan', 'bartlett p', 'd d lewis', 'freund y', 'lewis d', 'schapire robert', 'umesh vazarani', 'freund v', 'david p helmbold', 'kautz h a', 'mansour y', 'haussler david', 'h kautz', 'james p callan', 'sally a goldman', 'sellie l', 'leonard pitt', 'dietterich t g', 'ng a', 'h a kautz', 'callan j p', 'tishby n', 's schapire', 'm k war-muth', 'm warmuth', 'kearns', 'sellie lm', 'nick littlestone', 'vazirani u v', 'furst m', 'y freund', 'linda sellie', 'freud y', 'helmbold', 'l m sel-lie', 're', 'drucker h', 'h s seung', 'selman bart ppear', 't dietterich', 'vazirani u', 'satinder singh', 'valiant l g', 'patrice simard', 'li m', 'papka r', 'r rivest', 'singer y', 'schapire re', 'l m sellie', 'ming li', 'h sebastian seung', 'kautz h', 'mj kearns', 'robert e shapire', 'lg valiant', 'seung h s', 're schapire', 'u v varizani', 'henry kautz', 'm kearns', 'david haussler', 'kearns mj', 'yoram singer', 'hart p', 'seung h', 'm', 'ymansour', 'michael j kerns', 'shapire r', 'j p kearns', 'simard patrice up ', 'm li', 'warmuth mk', 'cesa-bianchi n', 'war-muth m k', 'naftali tishby', 'r l rivest', 'david p helm-bold', 'r schapire', 'kearns michael', 'yoav freund', 's seung', 'rubinfeld r', 'dp helmbold', 'rudich s', 'warmuth', 'rivest r', 'manfred k warmuth', 'm furst', 'valiant leslie', 'jackson j', 'goldman s', 'ehrenfeucht a', 'h drucker', 'simard p', 'r e shapire', 'robert schapire', 'y mansour', 'e shamir', 'm war-muth', 'ron papka', 'eric bauer', 'sa goldman', 'd helmbold', 'd haussler', 'p simard', 'ha kautz', 't g dietterich', 'lee', 'david p helmhold', 'michael j kearns', 'lee w', 'ehrenfeucht andrzej', 'vazirani uv', 'valiant lg', 'rl rivest', 'drucker', 'a ng', 'leslie valient', 'ron d', 'd ron', 'l pitt', 'uv vazirani', 'helmbold d', 'umesh virkumar vazirani', 'p', 'mk warmuth', 'james callan', 'n littlestone', 'yishay mansour', 'drucker harris', 'dana ron', 'leslie valiant', 'valiant l', 'd lewis', 'haussler d', 'andrew y ng', 'w', 'j e payne', 'j jackson', 'simard r', 'r', 'w s lee', 'r shapire', 'r e schapire', 'm feder', 'bart selman', 'a ehrenfeucht', 'michael kearns', 'kearns michael j', 'robert', 'n cesa-bianchi', 'l sellie', 'r lipton', 'schapire robert e', 'p auer', 'd haus-sler', 'rob schapire', 'wolpert d h', 'nick lit-tlestone', 'robert e schapire', 'eli shamir', 'nicolo cesa-bianchi', 'william w cohen', 's goldman', 'l m sallie', 'h druker', 's a goldman', 'm kearns et al', 'helmbold d p', 'callan j', 'dietterich t', 'rivest ronald l', 'simard patrice', 'selman', 'b selman', 'david haus-sler', 'r ru-binfeld', 'n tishby', 'shamir e', 'l g valiant', 'umesh vazirani', 'steven rudich', 'manfred k war-muth', 'jeffrey jackson', 'd p helm-bold', 'schapire r', 'kautz henry a', 'w w cohen', 'jeffery jackson', 'harris drucker', 'kearns m', 'david lewis', 'p bartlett', 'y singer mk warmuth', 'rivest rl', 'goldman s a', 'm j kearns', 'ronald l rivest', 'richard j lipton', 's rudich', 'kearns m j', 'linda m sellie', 'lenny pitt', 'm k warmuth', 'micahel kearns', 'leslie g valiant', 'r papka', 'pitt l', 'rivest r l', 'seung hs', 'ptrice simard', 'schapire r e', 'j p callan', 'man-fred k warmuth', 'seung', 'dh helmbold', 'e schapire', 'r rubinfeld', 'schapire', 'a y ng', 'avrim blum', 'ronitt rubenfeld', 'goldman sa', 'u vazirani', 'd p helmbold', 'ng a y', 'lewis d d', 'sellie l m', 'l g', 'simard', 'selman b', 'henry a kautz', 'littlestone n'}
# {'n cesa bianchi', 'nicolo cesa bianchi', 'cesa bianchi n'}

# %%
# Anyway, 264 shouldn't be hard to hand cluster...
# But... Perhaps a good time to run dedupe and see how well it does...
import dedupe
fields = [{'field': 'name', 'type': 'String'}]
deduper = dedupe.Dedupe(fields)

data_d = {}
for index, row in dfauthors.iterrows():
    data_d[row['author_id']] = {'name': row['name']}

deduper.sample(data_d,)

author_name_clusters = list(uf_authors.getDisjointSets())

match = []
for author_name_cluster in author_name_clusters:
    for author_inst1 in author_name_cluster:
        for author_inst2 in author_name_cluster:
            match.append(({'name':author_inst1.replace('_',' ')},{'name':author_inst2.replace('_',' ')}))

from itertools import combinations
distinct = []
for author_name_cluster1,author_name_cluster2 in combinations(author_name_clusters,2):
    for author1 in author_name_cluster1:
        for author2 in author_name_cluster2:
            distinct.append(({'name':author1.replace('_',' ')},{'name':author2.replace('_',' ')}))
            
deduper.markPairs({'match':match, 'distinct':distinct})

# %%
deduper.train()
# Out:
# INFO:rlr.crossvalidation:using cross validation to find optimum alpha...
# INFO:rlr.crossvalidation:optimum alpha: 0.100000, score 0.644809872524
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (2, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (1, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (3, name)
# INFO:dedupe.blocking:Canopy: LevenshteinCanopyPredicate: (4, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.8, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.6, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.4, name)
# INFO:dedupe.blocking:Canopy: TfidfTextCanopyPredicate: (0.2, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.4, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.8, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.2, name)
# INFO:dedupe.blocking:Canopy: TfidfNGramCanopyPredicate: (0.6, name)
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:SimplePredicate: (tokenFieldPredicate, name)
# INFO:dedupe.training:SimplePredicate: (sortedAcronym, name)

# %%
with open(wdir+'/deduper.training.txt','w') as tf:
    deduper.writeTraining(tf)
with open(wdir+'/deduper.settings.txt','w') as ts:
    deduper.writeTraining(ts)
threshold = deduper.threshold(data_d, recall_weight=1)
print('clustering...')
clustered_dupes = deduper.match(data_d, threshold)
print('# duplicate sets', len(clustered_dupes))
# Out:
# INFO:dedupe.api:Maximum expected recall and precision
# INFO:dedupe.api:recall: 0.820
# INFO:dedupe.api:precision: 0.828
# INFO:dedupe.api:With threshold: 0.423
# clustering...
# # duplicate sets 87

# %%
import csv
cluster_membership = {}
cluster_id = 0
for (cluster_id, cluster) in enumerate(clustered_dupes):
    id_set, scores = cluster
    cluster_d = [data_d[c] for c in id_set]
    canonical_rep = dedupe.canonicalize(cluster_d)
    for record_id, score in zip(id_set, scores):
        cluster_membership[record_id] = {
            "cluster id" : cluster_id,
            "canonical representation" : canonical_rep,
            "confidence": score
        }

singleton_id = cluster_id + 1

with open(wdir+'/deduper.output.txt', 'w') as f_output, open(wdir+'/psl/AuthorNames.txt') as f_input:
    writer = csv.writer(f_output)
    reader = csv.reader(f_input, delimiter='\t')

    heading_row = next(reader)
    heading_row.insert(0, 'confidence_score')
    heading_row.insert(0, 'Cluster ID')
    canonical_keys = canonical_rep.keys()
    for key in canonical_keys:
        heading_row.append('canonical_' + key)

    writer.writerow(heading_row)

    for row in reader:
        row_id = int(row[0])
        if row_id in cluster_membership:
            cluster_id = cluster_membership[row_id]["cluster id"]
            canonical_rep = cluster_membership[row_id]["canonical representation"]
            row.insert(0, cluster_membership[row_id]['confidence'])
            row.insert(0, cluster_id)
            for key in canonical_keys:
                row.append(canonical_rep[key].encode('utf8'))
        else:
            row.insert(0, None)
            row.insert(0, singleton_id)
            singleton_id += 1
            for key in canonical_keys:
                row.append(None)
        writer.writerow(row)

# %%
# !head 'data/cora-uwash/deduper.output.txt'
# Out:
# Cluster ID,confidence_score,id,name,canonical_name
# 39,0.7173422575,0,h. drucker,b'harris drucker'
# 45,0.762571705487,1,r. schapire,b'r. e. schapire.'
# 61,0.977741758029,2,p. simard.,b'p. simard.'
# 39,0.7173422575,3,h. drucker,b'harris drucker'
# 45,0.762571705487,4,r. schapire,b'r. e. schapire.'
# 61,0.977741758029,5,p. simard.,b'p. simard.'
# 4,0.978106518586,6,drucker h.,b'drucker h.'
# 38,0.97618725402,7,schapire r.,b'schapire r.'
# 9,0.975046575069,8,simard p.,b'simard p.'

# %%
from collections import defaultdict
dfclusters = pd.read_csv(wdir+'/deduper.output.txt')
clusters = defaultdict(set)
for index,row in dfclusters.iterrows():
    clusters[row['Cluster ID']].add(row['name'])

# %%
with open(wdir+'/author.clusters','w') as f:
    for cluster in clusters.values():
        f.write('\t'.join(cluster)+'\n\n')

# %%
# After some corrections on dedupes clusters, I was able to create 51 clusters of names
#    i.e. reduce the number of clusters from 87 to 51
# Beware: Pitfalls that have not been accounted for include the possibilty that
#    two different entities with the same name may be in the same cluster.
#    Think of this as a cluster of name similarities rather than entities.

# Does the number of entities in this clustering equal 264
clusters_corrected = {}
cluster_id = 1
num_entities = 0
with open(wdir+'/authors.clusters.corrected') as f:
    for line in f:
        clusters_corrected[cluster_id] = set(line.strip().split('\t'))
        num_entities += len(clusters_corrected[cluster_id])
        cluster_id += 1
        
print(num_entities)
# Perhaps this is because of the non-replacement of the periods?
# Out:
# 326

# %%
# With replacement of periods
clusters_corrected_alt = {}
cluster_id = 1
num_entities = 0
with open(wdir+'/authors.clusters.corrected') as f:
    for line in f:
        clusters_corrected_alt[cluster_id] = set(line.replace('.','').strip().split('\t'))
        num_entities += len(clusters_corrected_alt[cluster_id])
        cluster_id += 1
        
print(num_entities)
# Out:
# 265

# %%
# Good. nearly there. what's the difference?
clusters_corrected_combo = set()
for cluster in clusters_corrected_alt.values():
    for authorname in cluster:
        clusters_corrected_combo.add(authorname)
        
clusters_corrected_combo - authors_all
# Out:
# {'simard patrice up'}

# %%
# Legit. It should really have showed up in the authors_all set. What's up?
dfrelevant.iloc[442]['authors']
# It's the extra space at the end. Nothing to worry about.
# Out:
# 'drucker harris, schapire robert, and simard patrice up .'

# %%
# So, now that  we have (possibly noisy) ground truth for authors, 
#    we can get to writing our blocking stats function.
def get_blocking_stats(blocks_dict, ground_truth_set, num_total_elements):
    '''
    Req: ground_truth_set is a set of tuples (el1,el2) s.t. el1 < el2
         blocks_dict      is a dict with block_key : set(el1, el2, ...)
    Modifies ground_truth_set.
    '''
    num_total_comparisons = num_total_elements * (num_total_elements - 1) / 2
    num_ground_truth_total = len(ground_truth_set)
    num_comparisons_after_blocking = 0
    for block in blocks_dict.values():
        num_comparisons_after_blocking += len(block)*(len(block)-1)/2
        for el1 in block:
            for el2 in block:
                if el1 == el2:
                    continue
                elif el1 > el2:
                    ground_truth_set.discard((el2, el1))
                else:
                    ground_truth_set.discard((el1, el2))
    num_blocked_ground_truth = num_ground_truth_total - len(ground_truth_set)
    recall = num_blocked_ground_truth / num_ground_truth_total
    reduction_ratio = num_comparisons_after_blocking / num_total_comparisons
    return recall, reduction_ratio

# %%
num_total_elements = len(dfauthors)

ground_truth_set = set()
for cluster in clusters_corrected:
    for author1,author2 in combinations(cluster,2):
        ground_truth_set.add((author1,author2))

recall, reduction_ratio = get_blocking_stats(blocks1, ground_truth_set, )
# Out:
# {1: {'p. auer'},
#  2: {'bartlett p.', 'p. bartlett', 'peter bartlett'},
#  3: {'eric bauer'},
#  4: {'a. blum', 'avrim blum', 'blum a.'},
#  5: {'callan j.',
#   'callan j. p.',
#   'j. callan',
#   'j. p. callan',
#   'james callan',
#   'james p. callan'},
#  6: {'cesa-bianchi n.', 'n. cesa-bianchi', 'nicolo cesa-bianchi'},
#  7: {'w. w. cohen', 'william w. cohen'},
#  8: {'d. ron', 'd. ron.', 'dana ron', 'dana ron.', 'ron d.'},
#  9: {'dietterich t.',
#   'dietterich t. g.',
#   't. dietterich',
#   't. g. dietterich',
#   'tom dietterich'},
#  10: {'drucker',
#   'drucker h.',
#   'drucker harris',
#   'h. drucker',
#   'h. druker',
#   'harris drucker'},
#  11: {'a. ehrenfeucht',
#   'andrzej ehrenfeucht',
#   'ehrenfeucht a.',
#   'ehrenfeucht andrzej'},
#  12: {'m. feder'},
#  13: {'freud y.',
#   'freund v.',
#   'freund y',
#   'freund y.',
#   'freund yoav',
#   'y. freund',
#   'y. freund.',
#   'yoav freund',
#   'yoav freund.'},
#  14: {'furst m.', 'm. furst', 'merrick furst'},
#  15: {'goldman s.',
#   'goldman s. a.',
#   'goldman s.a.',
#   's. a. goldman',
#   's. goldman',
#   's.a goldman',
#   's.a. goldman',
#   'sally a. goldman'},
#  16: {'hart p.'},
#  17: {'d. haus-sler',
#   'd. haussler',
#   'd. haussler.',
#   'david haus-sler',
#   'david haussler',
#   'haussler d',
#   'haussler d.',
#   'haussler david'},
#  18: {'d. helmbold',
#   'd. p. helm-bold',
#   'd. p. helmbold',
#   'd.h. helmbold',
#   'd.p. helmbold',
#   'david p. helm-bold',
#   'david p. helmbold',
#   'david p. helmhold',
#   'helmbold',
#   'helmbold d.',
#   'helmbold d. p.'},
#  19: {'h. a. kautz',
#   'h. kautz',
#   'h.a. kautz',
#   'henry a. kautz',
#   'henry kautz',
#   'kautz h.',
#   'kautz h. a.',
#   'kautz henry',
#   'kautz henry a.'},
#  20: {'j. jackson', 'jackson j.', 'jeffery jackson', 'jeffrey jackson'},
#  21: {'j. p. kearns'},
#  22: {'kearns',
#   'kearns m.',
#   'kearns m. j.',
#   'kearns m.j.',
#   'kearns michael',
#   'kearns michael j.',
#   'm j kearns',
#   'm kearns',
#   'm.',
#   'm. j. kearns',
#   'm. j. kearns.',
#   'm. kearns',
#   'm. kearns et al.',
#   'm. kearns.',
#   'm.j. kearns',
#   'm.j. kearns.',
#   'micahel kearns.',
#   'michael j. kearns',
#   'michael j. kearns.',
#   'michael j. kerns',
#   'michael kearns',
#   'michael kearns.'},
#  23: {'ron kohavi'},
#  24: {'lee',
#   'lee w.',
#   'lee w. s.',
#   'lee w.s.',
#   'w.',
#   'w. lee.',
#   'w. s. lee.',
#   'wee sun lee.'},
#  25: {'d. d. lewis',
#   'd. lewis',
#   'david d. lewis',
#   'david lewis',
#   'lewis d.',
#   'lewis d. d.'},
#  26: {'mansour y.',
#   'y. mansour',
#   'y. mansour.',
#   'y.mansour',
#   'yishay mansour',
#   'yishay mansour.'},
#  27: {'m. li', 'm. li.', 'ming li', 'ming li.'},
#  28: {'r. lipton.', 'richard j. lipton.'},
#  29: {'littlestone n',
#   'littlestone n.',
#   'n. littlestone',
#   'nick lit-tlestone',
#   'nick littlestone'},
#  30: {'a. ng',
#   'a. ng.',
#   'a. y. ng',
#   'a. y. ng.',
#   'andrew y. ng',
#   'ng a.',
#   'ng a. y.'},
#  31: {'papka r.', 'r. papka', 'r. papka.', 'ron papka.'},
#  32: {'j. e. payne.'},
#  33: {'l. pitt', 'l. pitt.', 'lenny pitt', 'leonard pitt', 'pitt l.'},
#  34: {'r.'},
#  35: {'r. l. rivest',
#   'r. l. rivest.',
#   'r. rivest',
#   'r.l. rivest',
#   'rivest r.',
#   'rivest r. l.',
#   'rivest r.l.',
#   'rivest ronald l.',
#   'ronald l. rivest',
#   'ronald. l. rivest'},
#  36: {'r. ru-binfeld',
#   'r. rubinfeld',
#   'ronitt rubenfeld',
#   'ronitt rubinfeld',
#   'rubinfeld r.'},
#  37: {'rudich s.', 's. rudich', 's. rudich.', 'steven rudich.'},
#  38: {'e. schapire',
#   'r. e. schapire',
#   'r. e. schapire.',
#   'r. e. shapire',
#   'r. e. shapire.',
#   'r. schapire',
#   'r. schapire.',
#   'r. shapire.',
#   'r.e.',
#   'r.e. schapire',
#   'r.e. schapire.',
#   'rob schapire',
#   'rob schapire.',
#   'robert',
#   'robert e schapire',
#   'robert e. schapire',
#   'robert e. schapire.',
#   'robert e. shapire',
#   'robert e. shapire.',
#   'robert schapire',
#   'robert schapire.',
#   'robert. e. schapire.',
#   's. schapire.',
#   'schapire',
#   'schapire r.',
#   'schapire r. e.',
#   'schapire r.e.',
#   'schapire robert',
#   'schapire robert e.',
#   'shapire r.',
#   'shapire r. e.'},
#  39: {'l. m. sallie',
#   'l. m. sel-lie.',
#   'l. m. sellie',
#   'l. m. sellie.',
#   'l. sellie',
#   'l. sellie.',
#   'l.m. sellie',
#   'l.m. sellie.',
#   'li m.',
#   'linda m. sellie.',
#   'linda sellie.',
#   'sellie l.',
#   'sellie l. m.',
#   'sellie l.m.'},
#  40: {'b. selman',
#   'b. selman.',
#   'bart selman',
#   'bart selman.',
#   'selman b.',
#   'selman bart',
#   'selman bart ppear.',
#   'selman.',
#   'selman. b'},
#  41: {'h. s. seung',
#   'h. sebastian seung',
#   'h. sebastian seung.',
#   'h. seung',
#   'h. seung.',
#   'h.s seung',
#   'h.s. seung',
#   's. seung',
#   'seung',
#   'seung h.',
#   'seung h. s.',
#   'seung h.s.'},
#  42: {'e shamir', 'e. shamir', 'eli shamir', 'shamir e.'},
#  43: {'p.',
#   'p. simard',
#   'p. simard.',
#   'patrice simard.',
#   'ptrice simard.',
#   'simard',
#   'simard p.',
#   'simard patrice',
#   'simard patrice up .',
#   'simard r.'},
#  44: {'singer y.',
#   'y. singer',
#   'y. singer m.k. warmuth',
#   'y. singer.',
#   'yoram singer',
#   'yoram singer.',
#   'yoram singer. boostexter:'},
#  45: {'satinder singh.'},
#  46: {'n tishby',
#   'n. tishby',
#   'n. tishby.',
#   'naftali tishby',
#   'naftali tishby.',
#   'tishby n.'},
#  47: {'l. g.',
#   'l. g. valiant',
#   'l. g. valiant.',
#   'l. valiant',
#   'l. valiant.',
#   'l.g. valiant',
#   'l.g. valiant.',
#   'leslie g. valiant.',
#   'leslie valiant.',
#   'leslie valient.'},
#  48: {'valiant',
#   'valiant l.',
#   'valiant l. g.',
#   'valiant l.g.',
#   'valiant leslie',
#   'valiant.'},
#  49: {'u v varizani.',
#   'u. v. vazirani.',
#   'u. vazirani',
#   'u. vazirani.',
#   'u.v. vazirani.',
#   'umesh v. vazirani.',
#   'umesh vazarani.',
#   'umesh vazirani.',
#   'umesh virkumar vazirani.',
#   'vazirani u.',
#   'vazirani u. v.',
#   'vazirani u.v.'},
#  50: {'m. k. war-muth.',
#   'm. k. warmuth',
#   'm. k. warmuth.',
#   'm. war muth.',
#   'm. war-muth.',
#   'm. warmuth.',
#   'm.k. warmuth',
#   'm.k. warmuth.',
#   'man-fred k. warmuth.',
#   'manfred k warmuth.',
#   'manfred k. war-muth.',
#   'manfred k. warmuth.',
#   'war-muth m. k.',
#   'warmuth',
#   'warmuth m.',
#   'warmuth m. k.',
#   'warmuth m.k.',
#   'y. singer m.k. warmuth'},
#  51: {'wolpert d. h.'}}

# %%
# 2. their blockcondition2 has a substring-superstring relationship
# 3. there is at least one 3 letter match in the intersection of blockcondition1

# %%
print(len(blocks))
num_comparisons = 0
num_elements_in_block = 0
for block in blocks.values():
    num_comparisons += len(block) * len(block) - 1
    num_of_elements_in_block +=
# Out:
# 245

# %%
authorname_to_ids = defaultdict(set)
for index, row in dfauthors.iterrows():
    authorname_to_ids[row['name']].add(row['author_id'])

# %%
clusters_by_id = defaultdict(set)
for key,cluster in clusters_corrected.items():
    for author in cluster:
        if author not in authorname_to_ids:
            print(author+" not found")
            continue
        clusters_by_id[key].update(authorname_to_ids[author])

# %%
def get_blocking_statistics(blocks, ground_truth, num_elements):
    
    # Get number of comparisons without blocking
    num_comparisons = num_elements * (num_elements - 1) / 2
    # Get number of comparisons after blocking
    num_comparisons_blocked = get_num_comparisons_blocked(blocks)
    compression = num_comparisons_blocked / num_comparisons
    
    num_ground_truth = len(ground_truth)
    num_ground_truth_blocked = get_num_ground_truth_blocked(blocks, ground_truth)
    recall = num_ground_truth_blocked / num_ground_truth
    
    print("Recall:", recall)
    print("Compression:", compression)
    
    return recall, compression

# %%
def get_num_comparisons_blocked(blocks):

    num_blocked_pairs = 0
    for block in blocks.values():
        l = len(blocks)
        num_blocked_pairs += l * (l-1) / 2

    return num_blocked_pairs

# %%
def get_num_ground_truth_blocked(blocks, ground_truth):
    
    num_ground_truth_blocked = 0
    for e1, e2 in ground_truth:
        for block in blocks.values():
            if e1 in block and e2 in block:
                num_ground_truth_blocked += 1
                break
                
    return num_ground_truth_blocked

# %%
ground_truth = set()
for cluster in clusters_by_id.values():
    for authid1,authid2 in combinations(cluster,2):
        ground_truth.add((authid1,authid2))
        
len(ground_truth)
# Out:
# 599646

# %%
# %%time
# Two author mentions are in the same block if 
# 1a. intersection of their blockcondition1 has at least two elements
dfauthors['bc'] = dfauthors['name'].apply(lambda x : set(part_of_name.replace('.','')[:3] for part_of_name in x.replace('.','. ').split()))

blockkeys = set()
for set1,set2 in combinations(dfauthors['bc'],2):
    if len(set1 & set2) > 1:
        blockkeys.add(tuple(set1 & set2))
        
blocks1 = defaultdict(set)
for blockkey in blockkeys:
    for index, row in dfauthors.iterrows():
        if row['bc'] & set(blockkey) == set(blockkey):
            blocks1[blockkey].add(row['author_id'])
            
recall, compression = get_blocking_statistics(blocks1, ground_truth, len(dfauthors))
print("Number of blocks:",len(blocks1))
# Out:
# Recall: 0.699476024187604
# Compression: 0.19682050443882765
# Number of blocks: 135
# CPU times: user 31 s, sys: 0 ns, total: 31 s
# Wall time: 31 s

# %%
# What's wrong about this?
get_blocking_stats(blocks1, ground_truth, len(dfauthors))
# Out:
# (0.4143844868472399, 0.10864920600457478)

# %%
# %%time
# Two author mentions are in the same block if 
# 1b. intersection of their blockcondition1 has at least one element
# TODO:
# I'm pretty sure there's a way to reduce redundancy of num comparisons here... 
# Authors with {a','b','c'} appear in both {'a','b'} as well as {'a','c'} etc.
dfauthors['bc'] = dfauthors['name'].apply(lambda x : set(part_of_name.replace('.','')[:3] for part_of_name in x.replace('.','. ').split()))

blockkeys = set()
for set1,set2 in combinations(dfauthors['bc'],2):
    if len(set1 & set2):
        blockkeys.add(tuple(set1 & set2))
        
blocks2 = defaultdict(set)
for blockkey in blockkeys:
    for index, row in dfauthors.iterrows():
        if row['bc'] & set(blockkey) == set(blockkey):
            blocks2[blockkey].add(row['author_id'])
            
recall, compression = get_blocking_statistics(blocks2, ground_truth, len(dfauthors))
print("Number of blocks:",len(blocks2))
# Out:
# Recall: 0.9877179193648515
# Compression: 0.6037327834947855
# Number of blocks: 196
# CPU times: user 41.3 s, sys: 0 ns, total: 41.3 s
# Wall time: 41.3 s

# %%
# What's wrong about this?
get_blocking_stats(blocks2, ground_truth, len(dfauthors))
# Out:
# (0.3103781160831753, 0.33406689197281175)

# %%
# %%time
# Two author mentions are in the same block if 
# 2. Their initials have a substring superstring relationship
dfauthors['bc'] = dfauthors['name'].apply(lambda x : ''.join(sorted([part_of_name[0] for part_of_name in x.replace('.','. ').split() if (part_of_name !='' and part_of_name !='.')])))

blockkeys = set()
for key in  dfauthors['bc'].unique():
    blockkeys.add(key)
        
blocks3 = defaultdict(set)
for blockkey in blockkeys:
    for index, row in dfauthors.iterrows():
        if row['bc'] in blockkey:
            blocks3[blockkey].add(row['author_id'])
            
recall, compression = get_blocking_statistics(blocks3, ground_truth, len(dfauthors))
print("Number of blocks:",len(blocks3))
# Out:
# Recall: 0.9879485821358803
# Compression: 0.04230172035700176
# Number of blocks: 81
# CPU times: user 16.1 s, sys: 0 ns, total: 16.1 s
# Wall time: 16.1 s

# %%
with open('data/cora-uwash/psl/BlocksAuthors.txt','w') as f:
    for blockid,block in blocks3.items():
        for authid in block:
            f.write('{}\t{}\n'.format(authid,blockid))

# %%
# !wc -l data/cora-uwash/psl/BlocksAuthors.txt
# Out:
# 7388 data/cora-uwash/psl/BlocksAuthors.txt
